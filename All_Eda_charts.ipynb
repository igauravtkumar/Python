# %% [markdown]
# 1️⃣** Histogram 📊 (For Single Numeric Column)**

# %%
# ✅ Used for: Understanding the distribution of a numerical column.
# ✅ Best for: Checking skewness, normality, or outliers.
# 🔹 X-axis: Values of the column
# 🔹 Y-axis: Frequency (count of values in each bin)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'Age': [22, 25, 30, 30, 35, 40, 45, 50, 55, 60, 65, 70]})
plt.hist(df['Age'], bins=5, color='blue', edgecolor='black')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# # **2  Box Plot 📦 (For Outliers & Distribution)**

# %%
# Used for: Detecting outliers, median, and quartiles in numerical data.
# Best for: Comparing distributions across different categories.
#  X-axis: Categories
#  Y-axis: Numeric values

# %%
import seaborn as sns

df = pd.DataFrame({
    'Department': ['HR', 'HR', 'IT', 'IT', 'Sales', 'Sales'],
    'Salary': [30000, 35000, 50000, 55000, 40000, 42000]
})

sns.boxplot(x='Department', y='Salary', data=df)
plt.show()

# %% [markdown]
# # **Scatter Plot 📈 (For Relationship Between Two Numeric Variables)**

# %%
# ✅ Used for: Checking the correlation between two numeric columns.
# ✅ Best for: Identifying patterns, clusters, or trends.
# 🔹 X-axis: One numeric variable
# 🔹 Y-axis: Another numeric variable

# %%
df = pd.DataFrame({'Ad_Spend': [100, 200, 300, 400, 500], 'Sales': [10, 20, 25, 40, 50]})

plt.scatter(df['Ad_Spend'], df['Sales'])
plt.xlabel("Advertising Spend")
plt.ylabel("Sales")
plt.title("Sales vs Advertising Spend")
plt.show()

# %% [markdown]
# # **Bar Chart 📊 (For Categorical Data)**

# %%
# ✅ Used for: Comparing categories based on a numeric value.
# ✅ Best for: Showing counts or percentages of different categories.
# 🔹 X-axis: Categories
# 🔹 Y-axis: Count or Numeric Value

# %%
df = pd.DataFrame({'Category': ['Electronics', 'Clothing', 'Food'], 'Sales': [5000, 7000, 4000]})
plt.bar(df['Category'], df['Sales'], color=['blue', 'green', 'red'])
plt.xlabel("Category")
plt.ylabel("Sales")
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# ## **Pie Chart 🍕 (For Percentage Breakdown of Categories)**

# %%
# ✅ Used for: Showing proportion of different categories.
# ✅ Best for: Visualizing market share, sales contribution, etc.
# 🔹 Each slice represents a category's proportion in total.

# %%
labels = ['Apple', 'Samsung', 'OnePlus']
sizes = [40, 35, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['red', 'blue', 'green'])
plt.title("Market Share Distribution")
plt.show()

# %% [markdown]
# # 6️⃣ Heatmap 🔥 (For Correlation Between Numeric Columns)

# %%
# ✅ Used for: Checking the relationship between multiple numeric columns.
# ✅ Best for: Finding which variables are related (correlation).

# %%
import seaborn as sns

df = pd.DataFrame({
    'Sales': [10, 20, 30, 40, 50],
    'Profit': [2, 5, 7, 10, 12],
    'Discount': [1, 2, 2, 3, 4]
})

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Line Plot:

# %%
# A line plot (or line chart) is used to visualize trends over time or show the relationship between two numeric variables.

# ✅ When to Use a Line Plot?
# ✔ Time Series Data (e.g., Sales over Months, Stock Prices over Time)
# ✔ Trend Analysis (e.g., Temperature changes over days)
# ✔ Comparing Multiple Series (e.g., Comparing Sales of different products)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample Data: Sales Over Time
data = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [1000, 1500, 1200, 1800, 2000, 2200]
})

# Plot Line Chart
plt.plot(data['Month'], data['Sales'], marker='o', linestyle='-', color='blue', label="Sales Trend")

# Labels and Title
plt.xlabel("Month")
plt.ylabel("Sales ($)")
plt.title("Monthly Sales Trend")
plt.legend()
plt.grid(True)

# Show Plot
plt.show()
