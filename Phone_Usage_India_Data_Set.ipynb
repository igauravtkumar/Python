# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/phone_usage_india.csv')
df
# Out:
#       User ID  Age  Gender   Location Phone Brand       OS  \
# 0      U00001   53    Male     Mumbai        Vivo  Android
# 1      U00002   60   Other      Delhi      Realme      iOS
# 2      U00003   37  Female  Ahmedabad       Nokia  Android
# 3      U00004   32    Male       Pune     Samsung  Android
# 4      U00005   16    Male     Mumbai      Xiaomi      iOS
# ...       ...  ...     ...        ...         ...      ...
# 17681  U17682   27   Other     Mumbai       Apple      iOS
# 17682  U17683   40  Female    Chennai        Oppo      iOS
# 17683  U17684   34  Female  Ahmedabad      Realme  Android
# 17684  U17685   22    Male  Hyderabad        Vivo  Android
# 17685  U17686   43   Other    Kolkata        Oppo      iOS
#
#        Screen Time (hrs/day)  Data Usage (GB/month)  \
# 0                        3.7                   23.9
# 1                        9.2                   28.1
# 2                        4.5                   12.3
# ...

# %%
df.head(5)
# Out:
#   User ID  Age  Gender   Location Phone Brand       OS  Screen Time (hrs/day)  \
# 0  U00001   53    Male     Mumbai        Vivo  Android                    3.7
# 1  U00002   60   Other      Delhi      Realme      iOS                    9.2
# 2  U00003   37  Female  Ahmedabad       Nokia  Android                    4.5
# 3  U00004   32    Male       Pune     Samsung  Android                   11.0
# 4  U00005   16    Male     Mumbai      Xiaomi      iOS                    2.2
#
#    Data Usage (GB/month)  Calls Duration (mins/day)  Number of Apps Installed  \
# 0                   23.9                       37.9                       104
# 1                   28.1                       13.7                       169
# 2                   12.3                       66.8                        96
# 3                   25.6                      156.2                       146
# 4                    2.5                      236.2                        86
#
# ...

# %%
x = df.groupby('Location')['OS'].value_counts()
x
# Out:
# Location   OS
# Ahmedabad  Android    901
#            iOS        884
# Bangalore  Android    918
#            iOS        868
# Chennai    iOS        906
#            Android    884
# Delhi      iOS        895
#            Android    880
# Hyderabad  iOS        856
#            Android    844
# Jaipur     Android    919
#            iOS        905
# Kolkata    Android    917
#            iOS        872
# Lucknow    iOS        857
#            Android    843
# Mumbai     iOS        883
#            Android    839
# Pune       iOS        909
#            Android    906
# Name: count, dtype: int64

# %%
s = df.groupby('Gender')['Phone Brand'].value_counts()
s
# Out:
# Gender  Phone Brand
# Female  Xiaomi          641
#         Realme          613
#         Vivo            612
#         Nokia           609
#         Samsung         604
#         OnePlus         600
#         Google Pixel    596
#         Oppo            581
#         Motorola        570
#         Apple           543
# Male    Apple           599
#         Nokia           596
#         Xiaomi          596
#         Realme          591
#         Samsung         590
#         Motorola        579
#         Vivo            579
#         Google Pixel    572
#         OnePlus         563
#         Oppo            560
# Other   OnePlus         644
#         Apple           633
#         Nokia           611
#         Vivo            606
#         Oppo            575
#         Samsung         570
#         Motorola        568
#         Xiaomi          566
#         Google Pixel    561
#         Realme          558
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'],color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df.sample(5)
# Out:
#       User ID  Age  Gender   Location Phone Brand       OS  \
# 3710   U03711   52   Other  Hyderabad      Realme  Android
# 9756   U09757   50  Female  Hyderabad      Xiaomi  Android
# 10358  U10359   58    Male    Lucknow        Oppo  Android
# 208    U00209   21    Male  Ahmedabad      Realme  Android
# 16836  U16837   31  Female  Ahmedabad      Realme      iOS
#
#        Screen Time (hrs/day)  Data Usage (GB/month)  \
# 3710                     9.7                   21.3
# 9756                     5.5                   16.8
# 10358                    3.4                   27.9
# 208                      2.7                   25.3
# 16836                   10.6                    4.7
#
#        Calls Duration (mins/day)  Number of Apps Installed  \
# 3710                       115.0                       197
# 9756                       142.4                        59
# 10358                      223.3                       148
# ...

# %%
k = df.groupby('Gender')['Primary Use'].value_counts()
k
# Out:
# Gender  Primary Use
# Female  Work             1226
#         Education        1219
#         Gaming           1203
#         Social Media     1197
#         Entertainment    1124
# Male    Entertainment    1207
#         Work             1172
#         Education        1171
#         Social Media     1160
#         Gaming           1115
# Other   Gaming           1258
#         Education        1211
#         Work             1159
#         Social Media     1144
#         Entertainment    1120
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    5969
# Other     5892
# Male      5825
# Name: count, dtype: int64
