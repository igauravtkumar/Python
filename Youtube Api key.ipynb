# %%
# !pip install google-api-python-client==2.65.0
# Out:
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.4 MB 495.5 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/10.4 MB 563.7 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/10.4 MB 654.9 kB/s eta 0:00:16
#     --------------------------------------- 0.2/10.4 MB 700.2 kB/s eta 0:00:15
#     --------------------------------------- 0.2/10.4 MB 801.7 kB/s eta 0:00:13
#    - -------------------------------------- 0.3/10.4 MB 905.4 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/10.4 MB 912.8 kB/s eta 0:00:12
# ...

# %%
from googleapiclient.discovery import build

# %%
api_key='AIzaSyBzsn25TuZ1Qb2N3b2hZWHf-AyNUTdQEi4'

# %%
youtube = build(
    'youtube',
    'v3',
    developerKey=api_key
)

# %%
request = youtube.channels().list(
    part = 'statistics',
    forUsername = 'BBCNews'
)

# %%
data = request.execute()

# %%
data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'LZuSdJq1CKOZZHMpGe0RtLUrIJU',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'hkFK_hv0KdIMqXLvnx0mjWVqgmw',
#    'id': 'UC16niRr50-MSBwiO3YDb3RA',
#    'statistics': {'viewCount': '6078097591',
#     'subscriberCount': '18000000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '25508'}}]}

# %%
import pandas as pd

# Sample YouTube API response
data = {
    'kind': 'youtube#channelListResponse',
    'etag': 'weD6vLCDb_ofofOzQady15jHV5A',
    'pageInfo': {
        'totalResults': 1,
        'resultsPerPage': 5
    },
    'items': [{
        'kind': 'youtube#channel',
        'etag': '8fHfP4W1mth7Bq461HQvdTzmzeI',
        'id': 'UC16niRr50-MSBwiO3YDb3RA',
        'statistics': {
            'viewCount': '6078097591',
            'subscriberCount': '18000000',
            'hiddenSubscriberCount': False,
            'videoCount': '25501'
        }
    }]
}

# Extract and flatten data
channel_data = []

for item in data['items']:
    stats = item['statistics']
    channel_data.append({
        'channel_id': item['id'],
        'view_count': int(stats['viewCount']),
        'subscriber_count': int(stats['subscriberCount']),
        'hidden_subscriber_count': stats['hiddenSubscriberCount'],
        'video_count': int(stats['videoCount'])
    })

# Convert to DataFrame
df = pd.DataFrame(channel_data)

# Display the DataFrame
df
# Out:
#                  channel_id  view_count  subscriber_count  \
# 0  UC16niRr50-MSBwiO3YDb3RA  6078097591          18000000
#
#    hidden_subscriber_count  video_count
# 0                    False        25501

# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/45.0 kB 682.7 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 445.3 kB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine

# Sample DataFrame (replace with your actual df)
df = pd.DataFrame({
    'id': ['UC16niRr50-MSBwiO3YDb3RA'],
    'viewCount': ['6078097591'],
    'subscriberCount': ['18000000'],
    'videoCount': ['25501']
})

# Step 1: Create connection string
username = 'root'
password = 'anilchanda'
host = 'localhost'   # or '127.0.0.1'
port = '3306'        # default MySQL port
database = 'gaurav'

# Step 2: Create SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Step 3: Upload DataFrame to MySQL
df.to_sql(name='youtube_stats', con=engine, if_exists='replace', index=False)

print("✅ Data uploaded to MySQL!")
# Out:
# ✅ Data uploaded to MySQL!
