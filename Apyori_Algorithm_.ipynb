# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/market_basket.csv', header = None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=3e60383e9ef7c661d62b8bd3982120418a5730cca9dfbcbf5ca78eab838f2848
#   Stored in directory: /root/.cache/pip/wheels/77/3d/a6/d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
transactions = []
for i in range(0,7501):
  transactions.append([str(df.values[i,j]) for j in range(0,20)])

# Training the dataset
from apyori import apriori
rules = apriori(transactions,
                min_support = 0.003, #(3 items * 7 days in week)/(total rows in dataset 7501)
                min_confidence = 0.2,
                min_left=3,
                min_length=2)

# visualize the results
a = list(rules)
result = [list(a[i][0]) for i in range(0,len(a))]

# %%
a
# Out:
# [RelationRecord(items=frozenset({'mineral water'}), support=0.23836821757099053, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'almonds', 'chocolate'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'chocolate'}), confidence=0.29411764705882354, lift=1.7950988369310295)]),
#  RelationRecord(items=frozenset({'eggs', 'almonds'}), support=0.006532462338354886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'eggs'}), confidence=0.3202614379084967, lift=1.7821076007059597)]),
#  RelationRecord(items=frozenset({'french fries', 'almonds'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'french fries'}), confidence=0.21568627450980393, lift=1.2619834205132914)]),
#  RelationRecord(items=frozenset({'almonds', 'green tea'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'green tea'}), confidence=0.24836601307189543, lift=1.879912678155689)]),
#  RelationRecord(items=frozenset({'milk', 'almonds'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'milk'}), confidence=0.25490196078431376, lift=1.9670983619785367)]),
#  RelationRecord(items=frozenset({'mineral water', 'almonds'}), support=0.007598986801759766, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'mineral water'}), confidence=0.37254901960784315, lift=1.5629139799096374)]),
#  RelationRecord(items=frozenset({'almonds', 'nan'}), support=0.020263964804692707, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'nan'}), confidence=0.9934640522875817, lift=0.9935965141612201)]),
#  RelationRecord(items=frozenset({'spaghetti', 'almonds'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'spaghetti'}), confidence=0.29411764705882354, lift=1.6892622286280516)]),
#  RelationRecord(items=frozenset({'antioxydant juice', 'nan'}), support=0.008798826823090255, ordered_statistics=[OrderedStatistic(items_base=frozenset({'antioxydant juice'}), items_add=frozenset({'nan'}), confidence=0.9850746268656716, lift=0.9852059701492537)]),
#  RelationRecord(items=frozenset({'asparagus', 'nan'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'asparagus'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chocolate', 'avocado'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'chocolate'}), confidence=0.212, lift=1.293907241659886)]),
#  RelationRecord(items=frozenset({'french fries', 'avocado'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'french fries'}), confidence=0.24000000000000002, lift=1.4042433697347896)]),
#  RelationRecord(items=frozenset({'milk', 'avocado'}), support=0.007465671243834155, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'milk'}), confidence=0.22399999999999998, lift=1.728625514403292)]),
#  RelationRecord(items=frozenset({'mineral water', 'avocado'}), support=0.011598453539528063, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'mineral water'}), confidence=0.348, lift=1.4599261744966443)]),
#  RelationRecord(items=frozenset({'nan', 'avocado'}), support=0.03319557392347687, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'nan'}), confidence=0.996, lift=0.9961328)]),
#  RelationRecord(items=frozenset({'spaghetti', 'avocado'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'avocado'}), items_add=frozenset({'spaghetti'}), confidence=0.24000000000000002, lift=1.37843797856049)]),
#  RelationRecord(items=frozenset({'nan', 'babies food'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'babies food'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'bacon', 'mineral water'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'mineral water'}), confidence=0.35384615384615387, lift=1.4844519015659956)]),
#  RelationRecord(items=frozenset({'bacon', 'nan'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'bacon', 'spaghetti'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.36923076923076925, lift=2.1206738131699847)]),
#  RelationRecord(items=frozenset({'eggs', 'barbecue sauce'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'eggs'}), confidence=0.3333333333333333, lift=1.8548466864490603)]),
#  RelationRecord(items=frozenset({'mineral water', 'barbecue sauce'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'mineral water'}), confidence=0.35802469135802467, lift=1.501981661004778)]),
#  RelationRecord(items=frozenset({'barbecue sauce', 'nan'}), support=0.010798560191974404, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'black tea'}), support=0.004932675643247567, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'eggs'}), confidence=0.34579439252336447, lift=1.924186749493885)]),
#  RelationRecord(items=frozenset({'milk', 'black tea'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'milk'}), confidence=0.29906542056074764, lift=2.3079112341833006)]),
#  RelationRecord(items=frozenset({'mineral water', 'black tea'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'mineral water'}), confidence=0.37383177570093457, lift=1.5682953856446926)]),
#  RelationRecord(items=frozenset({'black tea', 'nan'}), support=0.014264764698040262, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'black tea'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'spaghetti'}), confidence=0.3177570093457944, lift=1.8250347068168482)]),
#  RelationRecord(items=frozenset({'mineral water', 'blueberries'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'mineral water'}), confidence=0.3913043478260869, lift=1.6415961482346075)]),
#  RelationRecord(items=frozenset({'blueberries', 'nan'}), support=0.009198773496867084, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'blueberries'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'blueberries'}), items_add=frozenset({'spaghetti'}), confidence=0.37681159420289856, lift=2.164214217546663)]),
#  RelationRecord(items=frozenset({'french fries', 'body spray'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'french fries'}), confidence=0.37209302325581395, lift=2.17712150346479)]),
#  RelationRecord(items=frozenset({'mineral water', 'body spray'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'mineral water'}), confidence=0.3604651162790698, lift=1.5122197076114667)]),
#  RelationRecord(items=frozenset({'body spray', 'nan'}), support=0.011465137981602452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'brownies'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'eggs'}), confidence=0.21739130434782608, lift=1.2096826215972132)]),
#  RelationRecord(items=frozenset({'french fries', 'brownies'}), support=0.007865617917610986, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'french fries'}), confidence=0.23320158102766797, lift=1.3644657248740544)]),
#  RelationRecord(items=frozenset({'mineral water', 'brownies'}), support=0.009598720170643914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'mineral water'}), confidence=0.2845849802371541, lift=1.1938881078069872)]),
#  RelationRecord(items=frozenset({'brownies', 'nan'}), support=0.03372883615517931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'brownies'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'spaghetti'}), confidence=0.21739130434782608, lift=1.2485851255076903)]),
#  RelationRecord(items=frozenset({'nan', 'bug spray'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bug spray'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'nan', 'burger sauce'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burger sauce'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'burgers', 'eggs'}), support=0.02879616051193174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'eggs'}), confidence=0.33027522935779813, lift=1.8378297443715457)]),
#  RelationRecord(items=frozenset({'burgers', 'french fries'}), support=0.021997067057725635, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'french fries'}), confidence=0.25229357798165136, lift=1.4761732671141707)]),
#  RelationRecord(items=frozenset({'burgers', 'green tea'}), support=0.0174643380882549, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'green tea'}), confidence=0.2003058103975535, lift=1.5161391360161947)]),
#  RelationRecord(items=frozenset({'burgers', 'ham'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'burgers'}), confidence=0.21105527638190955, lift=2.420681388594348)]),
#  RelationRecord(items=frozenset({'burgers', 'milk'}), support=0.01786428476203173, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'milk'}), confidence=0.20489296636085627, lift=1.581175041844427)]),
#  RelationRecord(items=frozenset({'burgers', 'mineral water'}), support=0.024396747100386616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'mineral water'}), confidence=0.2798165137614679, lift=1.1738834841861134)]),
#  RelationRecord(items=frozenset({'burgers', 'nan'}), support=0.0871883748833489, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'burgers', 'spaghetti'}), support=0.021463804826023197, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'spaghetti'}), confidence=0.24617737003058102, lift=1.4139176513012162)]),
#  RelationRecord(items=frozenset({'butter', 'chocolate'}), support=0.008265564591387815, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'chocolate'}), confidence=0.2743362831858407, lift=1.674366525774606)]),
#  RelationRecord(items=frozenset({'eggs', 'butter'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'eggs'}), confidence=0.20353982300884957, lift=1.1326054988051786)]),
#  RelationRecord(items=frozenset({'french fries', 'butter'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'french fries'}), confidence=0.20353982300884957, lift=1.1909143622382066)]),
#  RelationRecord(items=frozenset({'butter', 'green tea'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'green tea'}), confidence=0.2433628318584071, lift=1.842042988667923)]),
#  RelationRecord(items=frozenset({'milk', 'butter'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'milk'}), confidence=0.20353982300884957, lift=1.5707327287956592)]),
#  RelationRecord(items=frozenset({'nan', 'butter'}), support=0.030129316091187842, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'butter'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter'}), items_add=frozenset({'spaghetti'}), confidence=0.2079646017699115, lift=1.1944429386493922)]),
#  RelationRecord(items=frozenset({'eggs', 'cake'}), support=0.019064124783362217, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'eggs'}), confidence=0.23519736842105263, lift=1.308765178431985)]),
#  RelationRecord(items=frozenset({'cake', 'french fries'}), support=0.01786428476203173, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'french fries'}), confidence=0.22039473684210528, lift=1.289532699729042)]),
#  RelationRecord(items=frozenset({'cake', 'mineral water'}), support=0.027463004932675644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'mineral water'}), confidence=0.33881578947368424, lift=1.4213966649005065)]),
#  RelationRecord(items=frozenset({'cake', 'nan'}), support=0.08105585921877083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cake', 'spaghetti'}), support=0.018130915877882948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cake'}), items_add=frozenset({'spaghetti'}), confidence=0.2236842105263158, lift=1.2847283791408077)]),
#  RelationRecord(items=frozenset({'candy bars', 'nan'}), support=0.009732035728569524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'candy bars'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'carrots', 'chocolate'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'chocolate'}), confidence=0.22608695652173913, lift=1.3798846711713304)]),
#  RelationRecord(items=frozenset({'carrots', 'green tea'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'green tea'}), confidence=0.23478260869565218, lift=1.7770982319133068)]),
#  RelationRecord(items=frozenset({'mineral water', 'carrots'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'mineral water'}), confidence=0.34782608695652173, lift=1.45919657620854)]),
#  RelationRecord(items=frozenset({'carrots', 'nan'}), support=0.01533128916144514, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'carrots'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'carrots'}), items_add=frozenset({'spaghetti'}), confidence=0.30434782608695654, lift=1.7480191757107666)]),
#  RelationRecord(items=frozenset({'cauliflower', 'nan'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cauliflower'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cereals', 'chocolate'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'chocolate'}), confidence=0.21761658031088085, lift=1.3281871187240986)]),
#  RelationRecord(items=frozenset({'cereals', 'green tea'}), support=0.006532462338354886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'green tea'}), confidence=0.2538860103626943, lift=1.9216942116352878)]),
#  RelationRecord(items=frozenset({'cereals', 'milk'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'milk'}), confidence=0.2746113989637306, lift=2.119197637476279)]),
#  RelationRecord(items=frozenset({'cereals', 'mineral water'}), support=0.010265297960271964, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'mineral water'}), confidence=0.3989637305699482, lift=1.6737287153272828)]),
#  RelationRecord(items=frozenset({'cereals', 'nan'}), support=0.025729902679642713, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cereals', 'spaghetti'}), support=0.006665777896280496, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cereals'}), items_add=frozenset({'spaghetti'}), confidence=0.2590673575129534, lift=1.4879511858381802)]),
#  RelationRecord(items=frozenset({'chocolate', 'champagne'}), support=0.011598453539528063, ordered_statistics=[OrderedStatistic(items_base=frozenset({'champagne'}), items_add=frozenset({'chocolate'}), confidence=0.24786324786324784, lift=1.5127926950546964)]),
#  RelationRecord(items=frozenset({'nan', 'champagne'}), support=0.04679376083188908, ordered_statistics=[OrderedStatistic(items_base=frozenset({'champagne'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chicken', 'chocolate'}), support=0.014664711371817091, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'chocolate'}), confidence=0.24444444444444446, lift=1.4919265889160112)]),
#  RelationRecord(items=frozenset({'eggs', 'chicken'}), support=0.01439808025596587, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'eggs'}), confidence=0.24, lift=1.3354896142433235)]),
#  RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'milk', 'chicken'}), support=0.014798026929742702, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'milk'}), confidence=0.24666666666666667, lift=1.9035459533607684)]),
#  RelationRecord(items=frozenset({'mineral water', 'chicken'}), support=0.022796960405279298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'mineral water'}), confidence=0.38000000000000006, lift=1.5941722595078303)]),
#  RelationRecord(items=frozenset({'chicken', 'nan'}), support=0.05999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'chicken'}), support=0.01719770697240368, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'spaghetti'}), confidence=0.2866666666666667, lift=1.6464675855028077)]),
#  RelationRecord(items=frozenset({'nan', 'chili'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chili'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cooking oil', 'chocolate'}), support=0.013598186908412212, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'chocolate'}), confidence=0.26631853785900783, lift=1.6254315317171828)]),
#  RelationRecord(items=frozenset({'eggs', 'chocolate'}), support=0.03319557392347687, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'eggs'}), confidence=0.20260374288039054, lift=1.1273966434316094)]),
#  RelationRecord(items=frozenset({'escalope', 'chocolate'}), support=0.01759765364618051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'chocolate'}), confidence=0.22184873949579834, lift=1.3540174084279766)]),
#  RelationRecord(items=frozenset({'french fries', 'chocolate'}), support=0.03439541394480736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'french fries'}), confidence=0.209926769731489, lift=1.2282844771886887), OrderedStatistic(items_base=frozenset({'french fries'}), items_add=frozenset({'chocolate'}), confidence=0.20124804992199688, lift=1.2282844771886887)]),
#  RelationRecord(items=frozenset({'french wine', 'chocolate'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'french wine'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923078, lift=1.4084621643612694)]),
#  RelationRecord(items=frozenset({'fresh bread', 'chocolate'}), support=0.009465404612718305, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh bread'}), items_add=frozenset({'chocolate'}), confidence=0.21981424148606812, lift=1.3416001833905589)]),
#  RelationRecord(items=frozenset({'fresh tuna', 'chocolate'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh tuna'}), items_add=frozenset({'chocolate'}), confidence=0.2155688622754491, lift=1.3156892074272935)]),
#  RelationRecord(items=frozenset({'fromage blanc', 'chocolate'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'chocolate'}), confidence=0.22549019607843138, lift=1.3762424416471226)]),
#  RelationRecord(items=frozenset({'frozen smoothie', 'chocolate'}), support=0.01493134248766831, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen smoothie'}), items_add=frozenset({'chocolate'}), confidence=0.23578947368421052, lift=1.43910239390176)]),
#  RelationRecord(items=frozenset({'frozen vegetables', 'chocolate'}), support=0.022930275963204905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'chocolate'}), confidence=0.24055944055944053, lift=1.4682151046675047)]),
#  RelationRecord(items=frozenset({'grated cheese', 'chocolate'}), support=0.010931875749900012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grated cheese'}), items_add=frozenset({'chocolate'}), confidence=0.20865139949109412, lift=1.2734696074716818)]),
#  RelationRecord(items=frozenset({'ground beef', 'chocolate'}), support=0.023063591521130515, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'chocolate'}), confidence=0.23473541383989144, lift=1.4326691124597442)]),
#  RelationRecord(items=frozenset({'ham', 'chocolate'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'chocolate'}), confidence=0.23618090452261306, lift=1.441491427847128)]),
#  RelationRecord(items=frozenset({'light cream', 'chocolate'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923075, lift=1.4084621643612691)]),
#  RelationRecord(items=frozenset({'milk', 'chocolate'}), support=0.03212904946007199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'chocolate'}), confidence=0.2479423868312757, lift=1.5132757067708698)]),
#  RelationRecord(items=frozenset({'mineral water', 'chocolate'}), support=0.05265964538061592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'chocolate'}), confidence=0.220917225950783, lift=1.348332068231752)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'chocolate'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'chocolate'}), confidence=0.23076923076923078, lift=1.4084621643612694)]),
#  RelationRecord(items=frozenset({'nan', 'chocolate'}), support=0.1638448206905746, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'oil', 'chocolate'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'chocolate'}), confidence=0.26589595375722547, lift=1.6228523589364916)]),
#  RelationRecord(items=frozenset({'olive oil', 'chocolate'}), support=0.01639781362485002, ordered_statistics=[OrderedStatistic(items_base=frozenset({'olive oil'}), items_add=frozenset({'chocolate'}), confidence=0.24898785425101214, lift=1.5196565457582114)]),
#  RelationRecord(items=frozenset({'pancakes', 'chocolate'}), support=0.01986401813091588, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes'}), items_add=frozenset({'chocolate'}), confidence=0.20897615708274897, lift=1.2754517121868998)]),
#  RelationRecord(items=frozenset({'parmesan cheese', 'chocolate'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'parmesan cheese'}), items_add=frozenset({'chocolate'}), confidence=0.2147651006711409, lift=1.3107835802556778)]),
#  RelationRecord(items=frozenset({'pepper', 'chocolate'}), support=0.006399146780429276, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pepper'}), items_add=frozenset({'chocolate'}), confidence=0.24120603015075376, lift=1.4721614582268543)]),
#  RelationRecord(items=frozenset({'rice', 'chocolate'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rice'}), items_add=frozenset({'chocolate'}), confidence=0.2836879432624113, lift=1.7314428498058154)]),
#  RelationRecord(items=frozenset({'salmon', 'chocolate'}), support=0.010665244634048793, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salmon'}), items_add=frozenset({'chocolate'}), confidence=0.2507836990595611, lift=1.5306171901104701)]),
#  RelationRecord(items=frozenset({'shrimp', 'chocolate'}), support=0.017997600319957337, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'chocolate'}), confidence=0.251865671641791, lift=1.5372208323719074)]),
#  RelationRecord(items=frozenset({'soup', 'chocolate'}), support=0.010131982402346354, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soup'}), items_add=frozenset({'chocolate'}), confidence=0.20052770448548812, lift=1.2238879669207863)]),
#  RelationRecord(items=frozenset({'spaghetti', 'chocolate'}), support=0.03919477403012932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'spaghetti'}), confidence=0.23921887713588283, lift=1.3739516059695691), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'chocolate'}), confidence=0.22511485451761104, lift=1.3739516059695691)]),
#  RelationRecord(items=frozenset({'tomato sauce', 'chocolate'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'chocolate'}), confidence=0.3584905660377358, lift=2.1879883936932925)]),
#  RelationRecord(items=frozenset({'chocolate', 'tomatoes'}), support=0.013998133582189041, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'chocolate'}), confidence=0.2046783625730994, lift=1.2492208280397221)]),
#  RelationRecord(items=frozenset({'white wine', 'chocolate'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'white wine'}), items_add=frozenset({'chocolate'}), confidence=0.2096774193548387, lift=1.27973175148954)]),
#  RelationRecord(items=frozenset({'whole wheat pasta', 'chocolate'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'chocolate'}), confidence=0.21266968325791855, lift=1.297994543627052)]),
#  RelationRecord(items=frozenset({'whole wheat rice', 'chocolate'}), support=0.011998400213304892, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat rice'}), items_add=frozenset({'chocolate'}), confidence=0.20501138952164008, lift=1.2512534034188951)]),
#  RelationRecord(items=frozenset({'nan', 'chocolate bread'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate bread'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'chutney', 'nan'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chutney'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'cider'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'eggs'}), confidence=0.4050632911392405, lift=2.2539909101153137)]),
#  RelationRecord(items=frozenset({'milk', 'cider'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'milk'}), confidence=0.31645569620253167, lift=2.4421133510444344)]),
#  RelationRecord(items=frozenset({'cider', 'nan'}), support=0.010531929076123183, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cider'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'clothes accessories', 'nan'}), support=0.008398880149313425, ordered_statistics=[OrderedStatistic(items_base=frozenset({'clothes accessories'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'nan', 'cookies'}), support=0.08038928142914278, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cookies'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'cooking oil'}), support=0.011731769097453673, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'eggs'}), confidence=0.2297650130548303, lift=1.2785366193800312)]),
#  RelationRecord(items=frozenset({'milk', 'cooking oil'}), support=0.011465137981602452, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'milk'}), confidence=0.22454308093994776, lift=1.732816512479988)]),
#  RelationRecord(items=frozenset({'mineral water', 'cooking oil'}), support=0.020130649246767097, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'mineral water'}), confidence=0.3942558746736292, lift=1.6539783646123563)]),
#  RelationRecord(items=frozenset({'nan', 'cooking oil'}), support=0.0510598586855086, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'cooking oil'}), support=0.01586455139314758, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil'}), items_add=frozenset({'spaghetti'}), confidence=0.31070496083550914, lift=1.7845313255950643)]),
#  RelationRecord(items=frozenset({'nan', 'corn'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'corn'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'green tea'}), support=0.006399146780429276, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'green tea'}), confidence=0.200836820083682, lift=1.5201584131661945)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'mineral water'}), support=0.009598720170643914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'mineral water'}), confidence=0.30125523012552297, lift=1.263822976046727)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'nan'}), support=0.03172910278629516, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'nan'}), confidence=0.9958158995815899, lift=0.9959486750348674)]),
#  RelationRecord(items=frozenset({'cottage cheese', 'spaghetti'}), support=0.006932409012131715, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'spaghetti'}), confidence=0.21757322175732213, lift=1.2496299666169015)]),
#  RelationRecord(items=frozenset({'dessert wine', 'nan'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dessert wine'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'eggplant'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'eggs'}), confidence=0.2727272727272727, lift=1.517601834367413)]),
#  RelationRecord(items=frozenset({'mineral water', 'eggplant'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'mineral water'}), confidence=0.2828282828282828, lift=1.1865184281291663)]),
#  RelationRecord(items=frozenset({'eggplant', 'nan'}), support=0.013198240234635382, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'eggplant'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggplant'}), items_add=frozenset({'spaghetti'}), confidence=0.29292929292929293, lift=1.6824369266942008)]),
#  RelationRecord(items=frozenset({'eggs', 'french fries'}), support=0.036395147313691506, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'french fries'}), confidence=0.20252225519287834, lift=1.1849605586597352), OrderedStatistic(items_base=frozenset({'french fries'}), items_add=frozenset({'eggs'}), confidence=0.21294851794071765, lift=1.1849605586597352)]),
#  RelationRecord(items=frozenset({'eggs', 'french wine'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'french wine'}), items_add=frozenset({'eggs'}), confidence=0.2662721893491124, lift=1.4816822643232137)]),
#  RelationRecord(items=frozenset({'eggs', 'fresh bread'}), support=0.008665511265164644, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh bread'}), items_add=frozenset({'eggs'}), confidence=0.20123839009287925, lift=1.1197990831503615)]),
#  RelationRecord(items=frozenset({'eggs', 'fresh tuna'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh tuna'}), items_add=frozenset({'eggs'}), confidence=0.2634730538922156, lift=1.4661063629417723)]),
#  RelationRecord(items=frozenset({'eggs', 'fromage blanc'}), support=0.003999466737768298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'eggs'}), confidence=0.29411764705882354, lift=1.6366294292197592)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22797202797202798, lift=1.2685594820609658)]),
#  RelationRecord(items=frozenset({'eggs', 'ground beef'}), support=0.019997333688841486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.20352781546811397, lift=1.132538682363741)]),
#  RelationRecord(items=frozenset({'eggs', 'ham'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'eggs'}), confidence=0.23618090452261306, lift=1.3142381044689322)]),
#  RelationRecord(items=frozenset({'eggs', 'herb & pepper'}), support=0.012531662445007332, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.25336927223719674, lift=1.4098834651715229)]),
#  RelationRecord(items=frozenset({'eggs', 'light cream'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'eggs'}), confidence=0.2136752136752137, lift=1.1890042861852952)]),
#  RelationRecord(items=frozenset({'eggs', 'light mayo'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'eggs'}), confidence=0.20098039215686272, lift=1.1183634433001686)]),
#  RelationRecord(items=frozenset({'eggs', 'low fat yogurt'}), support=0.01679776029862685, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.21951219512195125, lift=1.2214844032713326)]),
#  RelationRecord(items=frozenset({'eggs', 'meatballs'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meatballs'}), items_add=frozenset({'eggs'}), confidence=0.21019108280254778, lift=1.1696167003723374)]),
#  RelationRecord(items=frozenset({'eggs', 'milk'}), support=0.03079589388081589, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'eggs'}), confidence=0.23765432098765432, lift=1.322436989412756)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.21364653243847875, lift=1.188844688294532)]),
#  RelationRecord(items=frozenset({'eggs', 'nan'}), support=0.17970937208372217, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'pancakes'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes'}), items_add=frozenset({'eggs'}), confidence=0.2286115007012623, lift=1.2721178536796502)]),
#  RelationRecord(items=frozenset({'eggs', 'parmesan cheese'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'parmesan cheese'}), items_add=frozenset({'eggs'}), confidence=0.22818791946308722, lift=1.269760818911437)]),
#  RelationRecord(items=frozenset({'eggs', 'red wine'}), support=0.007065724570057326, ordered_statistics=[OrderedStatistic(items_base=frozenset({'red wine'}), items_add=frozenset({'eggs'}), confidence=0.25118483412322273, lift=1.3977280717791496)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti'}), support=0.036528462871617116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'spaghetti'}), confidence=0.2032640949554896, lift=1.1674456173515526), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'eggs'}), confidence=0.20980091883614088, lift=1.1674456173515524)]),
#  RelationRecord(items=frozenset({'eggs', 'turkey'}), support=0.01946407145713905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey'}), items_add=frozenset({'eggs'}), confidence=0.31130063965884863, lift=1.7322448798820649)]),
#  RelationRecord(items=frozenset({'energy bar', 'milk'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'milk'}), confidence=0.20197044334975367, lift=1.5586217032577185)]),
#  RelationRecord(items=frozenset({'energy bar', 'mineral water'}), support=0.006799093454206106, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'mineral water'}), confidence=0.2512315270935961, lift=1.0539640294905281)]),
#  RelationRecord(items=frozenset({'energy bar', 'nan'}), support=0.027063058258898813, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'energy drink', 'french fries'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'french fries'}), confidence=0.22999999999999998, lift=1.3457332293291733)]),
#  RelationRecord(items=frozenset({'mineral water', 'energy drink'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'mineral water'}), confidence=0.21, lift=0.880989932885906)]),
#  RelationRecord(items=frozenset({'energy drink', 'nan'}), support=0.026529796027196375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy drink'}), items_add=frozenset({'nan'}), confidence=0.995, lift=0.9951326666666667)]),
#  RelationRecord(items=frozenset({'french fries', 'escalope'}), support=0.01639781362485002, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'french fries'}), confidence=0.20672268907563024, lift=1.2095373562841674)]),
#  RelationRecord(items=frozenset({'mineral water', 'escalope'}), support=0.017064391414478068, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'mineral water'}), confidence=0.21512605042016805, lift=0.9024946891508281)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'nan', 'escalope'}), support=0.0793227569657379, ordered_statistics=[OrderedStatistic(items_base=frozenset({'escalope'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
#  RelationRecord(items=frozenset({'mineral water', 'extra dark chocolate'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.47777777777777775, lift=2.0043686303753416)]),
#  RelationRecord(items=frozenset({'extra dark chocolate', 'nan'}), support=0.011998400213304892, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'spaghetti', 'extra dark chocolate'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'extra dark chocolate'}), items_add=frozenset({'spaghetti'}), confidence=0.34444444444444444, lift=1.9783137655266292)]),
#  RelationRecord(items=frozenset({'flax seed', 'green tea'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flax seed'}), items_add=frozenset({'green tea'}), confidence=0.3382352941176471, lift=2.560144239330445)]),
#  RelationRecord(items=frozenset({'flax seed', 'nan'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flax seed'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'french fries', 'fromage blanc'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'french fries'}), confidence=0.2745098039215686, lift=1.6061607170169159)]),
#  RelationRecord(items=frozenset({'french fries', 'frozen smoothie'}), support=0.014531395813891481, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen smoothie'}), items_add=frozenset({'french fries'}), confidence=0.22947368421052633, lift=1.3426537482551935)]),
#  RelationRecord(items=frozenset({'french fries', 'green tea'}), support=0.028529529396080524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea'}), items_add=frozenset({'french fries'}), confidence=0.21594349142280528, lift=1.263488400282732)]),
#  RelationRecord(items=frozenset({'french fries', 'ham'}), support=0.005599253432875617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'french fries'}), confidence=0.21105527638190955, lift=1.2348873854451667)]),
#  RelationRecord(items=frozenset({'hot dogs', 'french fries'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hot dogs'}), items_add=frozenset({'french fries'}), confidence=0.2263374485596708, lift=1.324303589427528)]),
#  RelationRecord(items=frozenset({'light mayo', 'french fries'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'french fries'}), confidence=0.2696078431372549, lift=1.577479275641614)]),
#  RelationRecord(items=frozenset({'french fries', 'muffins'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'muffins'}), items_add=frozenset({'french fries'}), confidence=0.22099447513812154, lift=1.2930417769196956)]),
# ...
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'green tea'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.2314814814814815, lift=1.2880879767007365)]),
#  RelationRecord(items=frozenset({'eggs', 'ground beef', 'frozen vegetables'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.20245398773006135, lift=2.0605255928944235), OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'frozen vegetables'}), confidence=0.22000000000000003, lift=2.3080000000000003), OrderedStatistic(items_base=frozenset({'ground beef', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.25984251968503935, lift=1.44590410990911)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'low fat yogurt'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.31578947368421056, lift=1.757223176635952)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'frozen vegetables'}), support=0.007332355685908546, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'milk'}), confidence=0.3374233128834356, lift=2.6039220884142495), OrderedStatistic(items_base=frozenset({'eggs', 'milk'}), items_add=frozenset({'frozen vegetables'}), confidence=0.2380952380952381, lift=2.497835497835498), OrderedStatistic(items_base=frozenset({'milk', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.3107344632768361, lift=1.7290943687237001)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water', 'frozen vegetables'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'mineral water'}), confidence=0.41717791411042937, lift=1.750140678826807), OrderedStatistic(items_base=frozenset({'mineral water', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.25373134328358204, lift=1.4118982240134637)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'frozen vegetables'}), support=0.021730435941874418, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.22797202797202798, lift=1.2685594820609658), OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.22797202797202798, lift=1.2685594820609658)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'pancakes'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables', 'pancakes'}), items_add=frozenset({'eggs'}), confidence=0.22772277227722773, lift=1.2671724887622293)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'shrimp'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.2641509433962264, lift=2.7711835334476844), OrderedStatistic(items_base=frozenset({'frozen vegetables', 'shrimp'}), items_add=frozenset({'eggs'}), confidence=0.22399999999999998, lift=1.2464569732937685)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti', 'frozen vegetables'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'frozen vegetables'}), items_add=frozenset({'spaghetti'}), confidence=0.26380368098159507, lift=1.5151542197878596), OrderedStatistic(items_base=frozenset({'spaghetti', 'frozen vegetables'}), items_add=frozenset({'eggs'}), confidence=0.20574162679425836, lift=1.144857524171908)]),
#  RelationRecord(items=frozenset({'eggs', 'frozen vegetables', 'tomatoes'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'tomatoes'}), items_add=frozenset({'frozen vegetables'}), confidence=0.25, lift=2.6227272727272726)]),
#  RelationRecord(items=frozenset({'eggs', 'grated cheese', 'mineral water'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'mineral water'}), confidence=0.4852941176470589, lift=2.0359011054086067), OrderedStatistic(items_base=frozenset({'grated cheese', 'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.2519083969465649, lift=1.4017543660950915)]),
#  RelationRecord(items=frozenset({'eggs', 'grated cheese', 'nan'}), support=0.009065457938941474, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'grated cheese', 'spaghetti'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'grated cheese'}), items_add=frozenset({'spaghetti'}), confidence=0.47058823529411764, lift=2.7028195658048824), OrderedStatistic(items_base=frozenset({'grated cheese', 'spaghetti'}), items_add=frozenset({'eggs'}), confidence=0.25806451612903225, lift=1.4360103378960467)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'green tea'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.2196969696969697, lift=1.2225125887959716)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water', 'green tea'}), support=0.006932409012131715, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'green tea'}), items_add=frozenset({'mineral water'}), confidence=0.2722513089005235, lift=1.1421460112208204), OrderedStatistic(items_base=frozenset({'mineral water', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.22317596566523604, lift=1.241871601227697)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'green tea'}), support=0.025463271563791495, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'green tea'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'pancakes', 'green tea'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.21951219512195122, lift=1.2214844032713323)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti', 'green tea'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'green tea'}), items_add=frozenset({'spaghetti'}), confidence=0.225130890052356, lift=1.293037370813723), OrderedStatistic(items_base=frozenset({'spaghetti', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.21608040201005024, lift=1.2023880530247677)]),
#  RelationRecord(items=frozenset({'eggs', 'turkey', 'green tea'}), support=0.0038661511798426876, ordered_statistics=[OrderedStatistic(items_base=frozenset({'turkey', 'green tea'}), items_add=frozenset({'eggs'}), confidence=0.32584269662921345, lift=1.8131647384389689)]),
#  RelationRecord(items=frozenset({'eggs', 'ground beef', 'herb & pepper'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'herb & pepper'}), confidence=0.2066666666666667, lift=4.178454627133872), OrderedStatistic(items_base=frozenset({'eggs', 'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3297872340425532, lift=3.3564912381997174), OrderedStatistic(items_base=frozenset({'ground beef', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.2583333333333333, lift=1.4375061819980215)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'ground beef'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'milk'}), confidence=0.29333333333333333, lift=2.2636762688614542), OrderedStatistic(items_base=frozenset({'milk', 'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.26666666666666666, lift=1.4838773491592483)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water', 'ground beef'}), support=0.010131982402346354, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'mineral water'}), confidence=0.5066666666666667, lift=2.125563012677107), OrderedStatistic(items_base=frozenset({'mineral water', 'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.247557003257329, lift=1.3775408615973477)]),
#  RelationRecord(items=frozenset({'eggs', 'ground beef', 'nan'}), support=0.019997333688841486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.20352781546811397, lift=1.132538682363741), OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'ground beef', 'nan'}), items_add=frozenset({'eggs'}), confidence=0.20352781546811397, lift=1.132538682363741)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti', 'ground beef'}), support=0.008932142381015865, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.4466666666666667, lift=2.565426237876468), OrderedStatistic(items_base=frozenset({'eggs', 'spaghetti'}), items_add=frozenset({'ground beef'}), confidence=0.2445255474452555, lift=2.4887193098871934), OrderedStatistic(items_base=frozenset({'spaghetti', 'ground beef'}), items_add=frozenset({'eggs'}), confidence=0.22789115646258504, lift=1.2681094693070107)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'ham'}), support=0.006265831222503666, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.23618090452261306, lift=1.3142381044689322), OrderedStatistic(items_base=frozenset({'eggs', 'ham'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'ham'}), items_add=frozenset({'eggs'}), confidence=0.23618090452261306, lift=1.3142381044689322)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'herb & pepper'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'herb & pepper'}), items_add=frozenset({'milk'}), confidence=0.26595744680851063, lift=2.0524144120479817), OrderedStatistic(items_base=frozenset({'milk', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.36231884057971014, lift=2.016137702662022)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water', 'herb & pepper'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'herb & pepper'}), items_add=frozenset({'mineral water'}), confidence=0.425531914893617, lift=1.7851873006806607), OrderedStatistic(items_base=frozenset({'mineral water', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.3125, lift=1.738918768545994)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'herb & pepper'}), support=0.012531662445007332, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.25336927223719674, lift=1.4098834651715229), OrderedStatistic(items_base=frozenset({'eggs', 'herb & pepper'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.25336927223719674, lift=1.4098834651715229)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti', 'herb & pepper'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'herb & pepper'}), items_add=frozenset({'spaghetti'}), confidence=0.3829787234042553, lift=2.1996350721709947), OrderedStatistic(items_base=frozenset({'spaghetti', 'herb & pepper'}), items_add=frozenset({'eggs'}), confidence=0.29508196721311475, lift=1.6419954273483484)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'honey'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'honey'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'hot dogs', 'nan'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'hot dogs'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'light cream'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.2136752136752137, lift=1.1890042861852952), OrderedStatistic(items_base=frozenset({'eggs', 'light cream'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'light cream'}), items_add=frozenset({'eggs'}), confidence=0.2136752136752137, lift=1.1890042861852952)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'light mayo'}), support=0.005465937874950006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light mayo'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.20098039215686272, lift=1.1183634433001686), OrderedStatistic(items_base=frozenset({'eggs', 'light mayo'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'light mayo', 'nan'}), items_add=frozenset({'eggs'}), confidence=0.20098039215686272, lift=1.1183634433001686)]),
#  RelationRecord(items=frozenset({'eggs', 'milk', 'low fat yogurt'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'low fat yogurt'}), items_add=frozenset({'milk'}), confidence=0.2222222222222222, lift=1.7149062642889803), OrderedStatistic(items_base=frozenset({'milk', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.2828282828282828, lift=1.5738093097143542)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water', 'low fat yogurt'}), support=0.0061325156645780565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'low fat yogurt'}), items_add=frozenset({'mineral water'}), confidence=0.36507936507936506, lift=1.5315773587585668), OrderedStatistic(items_base=frozenset({'mineral water', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.2555555555555556, lift=1.4220491262776132)]),
#  RelationRecord(items=frozenset({'eggs', 'nan', 'low fat yogurt'}), support=0.01679776029862685, ordered_statistics=[OrderedStatistic(items_base=frozenset({'low fat yogurt'}), items_add=frozenset({'eggs', 'nan'}), confidence=0.21951219512195125, lift=1.2214844032713326), OrderedStatistic(items_base=frozenset({'eggs', 'low fat yogurt'}), items_add=frozenset({'nan'}), confidence=1.0, lift=1.0001333333333333), OrderedStatistic(items_base=frozenset({'nan', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.2198952879581152, lift=1.2236161387046158)]),
#  RelationRecord(items=frozenset({'eggs', 'spaghetti', 'low fat yogurt'}), support=0.0037328356219170776, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'low fat yogurt'}), items_add=frozenset({'spaghetti'}), confidence=0.2222222222222222, lift=1.2763314616300834), OrderedStatistic(items_base=frozenset({'spaghetti', 'low fat yogurt'}), items_add=frozenset({'eggs'}), confidence=0.24561403508771928, lift=1.366729137383518)]),
#  ...]

# %%
result
# Out:
# [['mineral water'],
#  ['nan'],
#  ['burgers', 'almonds'],
#  ['almonds', 'chocolate'],
#  ['eggs', 'almonds'],
#  ['french fries', 'almonds'],
#  ['almonds', 'green tea'],
#  ['milk', 'almonds'],
#  ['mineral water', 'almonds'],
#  ['almonds', 'nan'],
#  ['spaghetti', 'almonds'],
#  ['antioxydant juice', 'nan'],
#  ['asparagus', 'nan'],
#  ['chocolate', 'avocado'],
#  ['french fries', 'avocado'],
#  ['milk', 'avocado'],
#  ['mineral water', 'avocado'],
#  ['nan', 'avocado'],
#  ['spaghetti', 'avocado'],
#  ['nan', 'babies food'],
#  ['bacon', 'mineral water'],
#  ['bacon', 'nan'],
#  ['bacon', 'spaghetti'],
#  ['eggs', 'barbecue sauce'],
#  ['mineral water', 'barbecue sauce'],
#  ['barbecue sauce', 'nan'],
#  ['eggs', 'black tea'],
#  ['milk', 'black tea'],
#  ['mineral water', 'black tea'],
#  ['black tea', 'nan'],
#  ['spaghetti', 'black tea'],
#  ['mineral water', 'blueberries'],
#  ['blueberries', 'nan'],
#  ['spaghetti', 'blueberries'],
#  ['french fries', 'body spray'],
#  ['mineral water', 'body spray'],
#  ['body spray', 'nan'],
#  ['eggs', 'brownies'],
#  ['french fries', 'brownies'],
#  ['mineral water', 'brownies'],
#  ['brownies', 'nan'],
#  ['spaghetti', 'brownies'],
#  ['nan', 'bug spray'],
#  ['nan', 'burger sauce'],
#  ['burgers', 'eggs'],
#  ['burgers', 'french fries'],
#  ['burgers', 'green tea'],
#  ['burgers', 'ham'],
#  ['burgers', 'milk'],
#  ['burgers', 'mineral water'],
#  ['burgers', 'nan'],
#  ['burgers', 'spaghetti'],
#  ['butter', 'chocolate'],
#  ['eggs', 'butter'],
#  ['french fries', 'butter'],
#  ['butter', 'green tea'],
#  ['milk', 'butter'],
#  ['nan', 'butter'],
#  ['spaghetti', 'butter'],
#  ['eggs', 'cake'],
#  ['cake', 'french fries'],
#  ['cake', 'mineral water'],
#  ['cake', 'nan'],
#  ['cake', 'spaghetti'],
#  ['candy bars', 'nan'],
#  ['carrots', 'chocolate'],
#  ['carrots', 'green tea'],
#  ['mineral water', 'carrots'],
#  ['carrots', 'nan'],
#  ['spaghetti', 'carrots'],
#  ['cauliflower', 'nan'],
#  ['cereals', 'chocolate'],
#  ['cereals', 'green tea'],
#  ['cereals', 'milk'],
#  ['cereals', 'mineral water'],
#  ['cereals', 'nan'],
#  ['cereals', 'spaghetti'],
#  ['chocolate', 'champagne'],
#  ['nan', 'champagne'],
#  ['chicken', 'chocolate'],
#  ['eggs', 'chicken'],
#  ['chicken', 'light cream'],
#  ['milk', 'chicken'],
#  ['mineral water', 'chicken'],
#  ['chicken', 'nan'],
#  ['spaghetti', 'chicken'],
#  ['nan', 'chili'],
#  ['cooking oil', 'chocolate'],
#  ['eggs', 'chocolate'],
#  ['escalope', 'chocolate'],
#  ['french fries', 'chocolate'],
#  ['french wine', 'chocolate'],
#  ['fresh bread', 'chocolate'],
#  ['fresh tuna', 'chocolate'],
#  ['fromage blanc', 'chocolate'],
#  ['frozen smoothie', 'chocolate'],
#  ['frozen vegetables', 'chocolate'],
#  ['grated cheese', 'chocolate'],
#  ['ground beef', 'chocolate'],
#  ['ham', 'chocolate'],
#  ['light cream', 'chocolate'],
#  ['milk', 'chocolate'],
#  ['mineral water', 'chocolate'],
#  ['mushroom cream sauce', 'chocolate'],
#  ['nan', 'chocolate'],
#  ['oil', 'chocolate'],
#  ['olive oil', 'chocolate'],
#  ['pancakes', 'chocolate'],
#  ['parmesan cheese', 'chocolate'],
#  ['pepper', 'chocolate'],
#  ['rice', 'chocolate'],
#  ['salmon', 'chocolate'],
#  ['shrimp', 'chocolate'],
#  ['soup', 'chocolate'],
#  ['spaghetti', 'chocolate'],
#  ['tomato sauce', 'chocolate'],
#  ['chocolate', 'tomatoes'],
#  ['white wine', 'chocolate'],
#  ['whole wheat pasta', 'chocolate'],
#  ['whole wheat rice', 'chocolate'],
#  ['nan', 'chocolate bread'],
#  ['chutney', 'nan'],
#  ['eggs', 'cider'],
#  ['milk', 'cider'],
#  ['cider', 'nan'],
#  ['clothes accessories', 'nan'],
#  ['nan', 'cookies'],
#  ['eggs', 'cooking oil'],
#  ['milk', 'cooking oil'],
#  ['mineral water', 'cooking oil'],
#  ['nan', 'cooking oil'],
#  ['spaghetti', 'cooking oil'],
#  ['nan', 'corn'],
#  ['cottage cheese', 'green tea'],
#  ['cottage cheese', 'mineral water'],
#  ['cottage cheese', 'nan'],
#  ['cottage cheese', 'spaghetti'],
#  ['dessert wine', 'nan'],
#  ['eggs', 'eggplant'],
#  ['mineral water', 'eggplant'],
#  ['eggplant', 'nan'],
#  ['spaghetti', 'eggplant'],
#  ['eggs', 'french fries'],
#  ['eggs', 'french wine'],
#  ['eggs', 'fresh bread'],
#  ['eggs', 'fresh tuna'],
#  ['eggs', 'fromage blanc'],
#  ['eggs', 'frozen vegetables'],
#  ['eggs', 'ground beef'],
#  ['eggs', 'ham'],
#  ['eggs', 'herb & pepper'],
#  ['eggs', 'light cream'],
#  ['eggs', 'light mayo'],
#  ['eggs', 'low fat yogurt'],
#  ['eggs', 'meatballs'],
#  ['eggs', 'milk'],
#  ['eggs', 'mineral water'],
#  ['eggs', 'nan'],
#  ['eggs', 'pancakes'],
#  ['eggs', 'parmesan cheese'],
#  ['eggs', 'red wine'],
#  ['eggs', 'spaghetti'],
#  ['eggs', 'turkey'],
#  ['energy bar', 'milk'],
#  ['energy bar', 'mineral water'],
#  ['energy bar', 'nan'],
#  ['energy drink', 'french fries'],
#  ['mineral water', 'energy drink'],
#  ['energy drink', 'nan'],
#  ['french fries', 'escalope'],
#  ['mineral water', 'escalope'],
#  ['mushroom cream sauce', 'escalope'],
#  ['nan', 'escalope'],
#  ['pasta', 'escalope'],
#  ['mineral water', 'extra dark chocolate'],
#  ['extra dark chocolate', 'nan'],
#  ['spaghetti', 'extra dark chocolate'],
#  ['flax seed', 'green tea'],
#  ['flax seed', 'nan'],
#  ['french fries', 'fromage blanc'],
#  ['french fries', 'frozen smoothie'],
#  ['french fries', 'green tea'],
#  ['french fries', 'ham'],
#  ['hot dogs', 'french fries'],
#  ['light mayo', 'french fries'],
#  ['french fries', 'muffins'],
#  ['french fries', 'mushroom cream sauce'],
#  ['french fries', 'nan'],
#  ['french fries', 'pancakes'],
#  ['rice', 'french fries'],
#  ['french fries', 'strawberries'],
#  ['tomato juice', 'french fries'],
#  ['french fries', 'vegetables mix'],
#  ['french wine', 'milk'],
#  ['french wine', 'mineral water'],
#  ['french wine', 'nan'],
#  ['french wine', 'spaghetti'],
#  ['fresh bread', 'milk'],
#  ['fresh bread', 'mineral water'],
#  ['fresh bread', 'nan'],
#  ['fresh bread', 'spaghetti'],
#  ['milk', 'fresh tuna'],
#  ['mineral water', 'fresh tuna'],
#  ['nan', 'fresh tuna'],
#  ['pancakes', 'fresh tuna'],
#  ['spaghetti', 'fresh tuna'],
#  ['fromage blanc', 'honey'],
#  ['mineral water', 'fromage blanc'],
#  ['nan', 'fromage blanc'],
#  ['spaghetti', 'fromage blanc'],
#  ['milk', 'frozen smoothie'],
#  ['mineral water', 'frozen smoothie'],
#  ['nan', 'frozen smoothie'],
#  ['spaghetti', 'frozen smoothie'],
#  ['milk', 'frozen vegetables'],
#  ['mineral water', 'frozen vegetables'],
#  ['nan', 'frozen vegetables'],
#  ['frozen vegetables', 'parmesan cheese'],
#  ['frozen vegetables', 'shrimp'],
#  ['spaghetti', 'frozen vegetables'],
#  ['frozen vegetables', 'tomatoes'],
#  ['nan', 'gluten free bar'],
#  ['grated cheese', 'ground beef'],
#  ['grated cheese', 'mineral water'],
#  ['grated cheese', 'nan'],
#  ['grated cheese', 'spaghetti'],
#  ['green beans', 'nan'],
#  ['spaghetti', 'green beans'],
#  ['mineral water', 'green grapes'],
#  ['green grapes', 'nan'],
#  ['green tea', 'gums'],
#  ['hot dogs', 'green tea'],
#  ['mineral water', 'green tea'],
#  ['nan', 'green tea'],
#  ['spaghetti', 'green tea'],
#  ['tomato juice', 'green tea'],
#  ['ground beef', 'herb & pepper'],
#  ['ground beef', 'light cream'],
#  ['milk', 'ground beef'],
#  ['mineral water', 'ground beef'],
#  ['ground beef', 'nan'],
#  ['olive oil', 'ground beef'],
#  ['pepper', 'ground beef'],
#  ['rice', 'ground beef'],
#  ['ground beef', 'salmon'],
#  ['spaghetti', 'ground beef'],
#  ['ground beef', 'tomato sauce'],
#  ['mineral water', 'gums'],
#  ['nan', 'gums'],
#  ['spaghetti', 'gums'],
#  ['mineral water', 'ham'],
#  ['nan', 'ham'],
#  ['spaghetti', 'ham'],
#  ['nan', 'hand protein bar'],
#  ['mineral water', 'herb & pepper'],
#  ['nan', 'herb & pepper'],
#  ['spaghetti', 'herb & pepper'],
#  ['mineral water', 'honey'],
#  ['nan', 'honey'],
#  ['spaghetti', 'honey'],
#  ['hot dogs', 'mineral water'],
#  ['hot dogs', 'nan'],
#  ['hot dogs', 'spaghetti'],
#  ['nan', 'ketchup'],
#  ['milk', 'light cream'],
#  ['mineral water', 'light cream'],
#  ['nan', 'light cream'],
#  ['olive oil', 'light cream'],
#  ['light cream', 'pancakes'],
#  ['spaghetti', 'light cream'],
#  ['light mayo', 'mineral water'],
#  ['light mayo', 'nan'],
#  ['light mayo', 'pancakes'],
#  ['mineral water', 'low fat yogurt'],
#  ['nan', 'low fat yogurt'],
#  ['mineral water', 'magazines'],
#  ['nan', 'magazines'],
#  ['mashed potato', 'nan'],
#  ['mayonnaise', 'nan'],
#  ['meatballs', 'milk'],
#  ['meatballs', 'mineral water'],
#  ['meatballs', 'nan'],
#  ['meatballs', 'spaghetti'],
#  ['melons', 'nan'],
#  ['milk', 'mineral water'],
#  ['milk', 'nan'],
#  ['milk', 'olive oil'],
#  ['milk', 'salmon'],
#  ['milk', 'shrimp'],
#  ['soup', 'milk'],
#  ['milk', 'spaghetti'],
#  ['milk', 'tomatoes'],
#  ['milk', 'white wine'],
#  ['milk', 'whole wheat pasta'],
#  ['milk', 'whole wheat rice'],
#  ['mineral water', 'mint'],
#  ['mineral water', 'nan'],
#  ['nonfat milk', 'mineral water'],
#  ['oil', 'mineral water'],
#  ['mineral water', 'olive oil'],
#  ['mineral water', 'pancakes'],
#  ['mineral water', 'parmesan cheese'],
#  ['mineral water', 'pepper'],
#  ['mineral water', 'protein bar'],
#  ['mineral water', 'red wine'],
#  ['rice', 'mineral water'],
#  ['mineral water', 'salmon'],
#  ['mineral water', 'shrimp'],
#  ['soup', 'mineral water'],
#  ['mineral water', 'spaghetti'],
#  ['mineral water', 'strawberries'],
#  ['mineral water', 'strong cheese'],
#  ['mineral water', 'tomato juice'],
#  ['mineral water', 'tomato sauce'],
#  ['mineral water', 'tomatoes'],
#  ['mineral water', 'turkey'],
#  ['mineral water', 'vegetables mix'],
#  ['mineral water', 'white wine'],
#  ['mineral water', 'whole weat flour'],
#  ['mineral water', 'whole wheat pasta'],
#  ['mineral water', 'whole wheat rice'],
#  ['mineral water', 'yams'],
#  ['mineral water', 'yogurt cake'],
#  ['mineral water', 'zucchini'],
#  ['nan', 'mint'],
#  ['spaghetti', 'mint'],
#  ['mint green tea', 'nan'],
#  ['muffins', 'nan'],
#  ['nan', 'mushroom cream sauce'],
#  ['spaghetti', 'mushroom cream sauce'],
#  ['nonfat milk', 'nan'],
#  ['nan', 'oatmeal'],
#  ['oil', 'nan'],
#  ['olive oil', 'nan'],
#  ['nan', 'pancakes'],
#  ['nan', 'parmesan cheese'],
#  ['pasta', 'nan'],
#  ['pepper', 'nan'],
#  ['pet food', 'nan'],
#  ['pickles', 'nan'],
#  ['protein bar', 'nan'],
#  ['red wine', 'nan'],
#  ['rice', 'nan'],
#  ['nan', 'salad'],
#  ['salmon', 'nan'],
#  ['salt', 'nan'],
#  ['sandwich', 'nan'],
#  ['shallot', 'nan'],
#  ['shampoo', 'nan'],
#  ['nan', 'shrimp'],
#  ['nan', 'soda'],
#  ['soup', 'nan'],
#  ['spaghetti', 'nan'],
#  ['sparkling water', 'nan'],
#  ['spinach', 'nan'],
#  ['nan', 'strawberries'],
#  ['nan', 'strong cheese'],
#  ['nan', 'tea'],
#  ['tomato juice', 'nan'],
#  ['tomato sauce', 'nan'],
#  ['nan', 'tomatoes'],
#  ['toothpaste', 'nan'],
#  ['turkey', 'nan'],
#  ['vegetables mix', 'nan'],
#  ['white wine', 'nan'],
#  ['whole weat flour', 'nan'],
#  ['whole wheat pasta', 'nan'],
#  ['whole wheat rice', 'nan'],
#  ['nan', 'yams'],
#  ['yogurt cake', 'nan'],
#  ['nan', 'zucchini'],
#  ['nonfat milk', 'spaghetti'],
#  ['oil', 'spaghetti'],
#  ['olive oil', 'spaghetti'],
#  ['olive oil', 'whole wheat pasta'],
#  ['spaghetti', 'pancakes'],
#  ['spaghetti', 'parmesan cheese'],
#  ['pasta', 'shrimp'],
#  ['spaghetti', 'pepper'],
#  ['spaghetti', 'protein bar'],
#  ['spaghetti', 'red wine'],
#  ['rice', 'spaghetti'],
#  ['spaghetti', 'salmon'],
#  ['spaghetti', 'shrimp'],
#  ['soup', 'spaghetti'],
#  ['spaghetti', 'strong cheese'],
#  ['spaghetti', 'tomato juice'],
#  ['spaghetti', 'tomato sauce'],
#  ['spaghetti', 'tomatoes'],
#  ['spaghetti', 'turkey'],
#  ['spaghetti', 'vegetables mix'],
#  ['spaghetti', 'white wine'],
#  ['spaghetti', 'whole wheat pasta'],
#  ['spaghetti', 'whole wheat rice'],
#  ['spaghetti', 'zucchini'],
#  ['burgers', 'almonds', 'nan'],
#  ['cake', 'almonds', 'nan'],
#  ['almonds', 'nan', 'chocolate'],
#  ['eggs', 'almonds', 'nan'],
#  ['french fries', 'almonds', 'nan'],
#  ['nan', 'almonds', 'frozen vegetables'],
#  ['almonds', 'nan', 'green tea'],
#  ['ground beef', 'almonds', 'nan'],
#  ['milk', 'almonds', 'nan'],
#  ['mineral water', 'almonds', 'nan'],
#  ['almonds', 'nan', 'pancakes'],
#  ['spaghetti', 'almonds', 'nan'],
#  ['burgers', 'nan', 'avocado'],
#  ['cake', 'nan', 'avocado'],
#  ['chocolate', 'mineral water', 'avocado'],
#  ['chocolate', 'nan', 'avocado'],
#  ['eggs', 'nan', 'avocado'],
#  ['french fries', 'nan', 'avocado'],
#  ['frozen smoothie', 'nan', 'avocado'],
#  ['nan', 'frozen vegetables', 'avocado'],
#  ['nan', 'green tea', 'avocado'],
#  ['ground beef', 'nan', 'avocado'],
#  ['nan', 'honey', 'avocado'],
#  ['milk', 'mineral water', 'avocado'],
#  ['milk', 'nan', 'avocado'],
#  ['milk', 'spaghetti', 'avocado'],
#  ['mineral water', 'nan', 'avocado'],
#  ['olive oil', 'nan', 'avocado'],
#  ['pancakes', 'nan', 'avocado'],
#  ['soup', 'nan', 'avocado'],
#  ['spaghetti', 'nan', 'avocado'],
#  ['nan', 'avocado', 'tomatoes'],
#  ['turkey', 'nan', 'avocado'],
#  ['whole wheat rice', 'nan', 'avocado'],
#  ['bacon', 'mineral water', 'nan'],
#  ['bacon', 'spaghetti', 'nan'],
#  ['eggs', 'barbecue sauce', 'nan'],
#  ['mineral water', 'barbecue sauce', 'nan'],
#  ['eggs', 'black tea', 'nan'],
#  ['milk', 'black tea', 'nan'],
#  ['mineral water', 'black tea', 'nan'],
#  ['spaghetti', 'black tea', 'nan'],
#  ['mineral water', 'blueberries', 'nan'],
#  ['spaghetti', 'blueberries', 'nan'],
#  ['french fries', 'body spray', 'nan'],
#  ['mineral water', 'body spray', 'nan'],
#  ['burgers', 'brownies', 'nan'],
#  ['cake', 'brownies', 'nan'],
#  ['brownies', 'nan', 'chocolate'],
#  ['cottage cheese', 'brownies', 'nan'],
#  ['eggs', 'mineral water', 'brownies'],
#  ['eggs', 'brownies', 'nan'],
#  ['french fries', 'brownies', 'nan'],
#  ['nan', 'brownies', 'frozen vegetables'],
#  ['brownies', 'nan', 'green tea'],
#  ['brownies', 'ground beef', 'nan'],
#  ['brownies', 'nan', 'low fat yogurt'],
#  ['milk', 'brownies', 'nan'],
#  ['mineral water', 'brownies', 'nan'],
#  ['olive oil', 'brownies', 'nan'],
#  ['brownies', 'nan', 'pancakes'],
#  ['brownies', 'nan', 'shrimp'],
#  ['spaghetti', 'brownies', 'nan'],
#  ['burgers', 'nan', 'butter'],
#  ['burgers', 'cake', 'chocolate'],
#  ['burgers', 'cake', 'eggs'],
#  ['burgers', 'cake', 'milk'],
#  ['burgers', 'cake', 'mineral water'],
#  ['burgers', 'cake', 'nan'],
#  ['burgers', 'cereals', 'nan'],
#  ['burgers', 'nan', 'champagne'],
#  ['burgers', 'chicken', 'nan'],
#  ['burgers', 'eggs', 'chocolate'],
#  ['burgers', 'french fries', 'chocolate'],
#  ['burgers', 'frozen vegetables', 'chocolate'],
#  ['burgers', 'green tea', 'chocolate'],
#  ['burgers', 'ground beef', 'chocolate'],
#  ['burgers', 'milk', 'chocolate'],
#  ['burgers', 'mineral water', 'chocolate'],
#  ['burgers', 'nan', 'chocolate'],
#  ['burgers', 'pancakes', 'chocolate'],
#  ['burgers', 'shrimp', 'chocolate'],
#  ['burgers', 'spaghetti', 'chocolate'],
#  ['burgers', 'turkey', 'chocolate'],
#  ['burgers', 'nan', 'cookies'],
#  ['burgers', 'nan', 'cooking oil'],
#  ['burgers', 'nan', 'cottage cheese'],
#  ['burgers', 'french fries', 'eggs'],
#  ['burgers', 'eggs', 'green tea'],
#  ['burgers', 'eggs', 'ground beef'],
#  ['burgers', 'milk', 'eggs'],
#  ['burgers', 'mineral water', 'eggs'],
#  ['burgers', 'eggs', 'nan'],
#  ['burgers', 'eggs', 'pancakes'],
#  ['burgers', 'spaghetti', 'eggs'],
#  ['burgers', 'turkey', 'eggs'],
#  ['burgers', 'nan', 'escalope'],
#  ['burgers', 'french fries', 'green tea'],
#  ['burgers', 'milk', 'french fries'],
#  ['burgers', 'mineral water', 'french fries'],
#  ['burgers', 'french fries', 'nan'],
#  ['burgers', 'french fries', 'pancakes'],
#  ['burgers', 'spaghetti', 'french fries'],
#  ['burgers', 'french wine', 'nan'],
#  ['burgers', 'fresh bread', 'nan'],
#  ['burgers', 'nan', 'fresh tuna'],
#  ['burgers', 'mineral water', 'frozen smoothie'],
#  ['burgers', 'nan', 'frozen smoothie'],
#  ['burgers', 'mineral water', 'frozen vegetables'],
#  ['burgers', 'nan', 'frozen vegetables'],
#  ['burgers', 'spaghetti', 'frozen vegetables'],
#  ['burgers', 'grated cheese', 'nan'],
#  ['burgers', 'milk', 'green tea'],
#  ['burgers', 'nan', 'green tea'],
#  ['burgers', 'spaghetti', 'green tea'],
#  ['burgers', 'milk', 'ground beef'],
#  ['burgers', 'mineral water', 'ground beef'],
#  ['burgers', 'ground beef', 'nan'],
#  ['burgers', 'spaghetti', 'ground beef'],
#  ['burgers', 'nan', 'ham'],
#  ['burgers', 'nan', 'herb & pepper'],
#  ['burgers', 'nan', 'honey'],
#  ['burgers', 'hot dogs', 'nan'],
#  ['burgers', 'nan', 'light mayo'],
#  ['burgers', 'nan', 'low fat yogurt'],
#  ['burgers', 'milk', 'mineral water'],
#  ['burgers', 'milk', 'nan'],
#  ['burgers', 'milk', 'spaghetti'],
#  ['burgers', 'milk', 'turkey'],
#  ['burgers', 'milk', 'whole wheat rice'],
#  ['burgers', 'mineral water', 'nan'],
#  ['burgers', 'mineral water', 'olive oil'],
#  ['burgers', 'mineral water', 'pancakes'],
#  ['burgers', 'mineral water', 'shrimp'],
#  ['burgers', 'mineral water', 'spaghetti'],
#  ['burgers', 'mineral water', 'tomatoes'],
#  ['burgers', 'mineral water', 'turkey'],
#  ['burgers', 'mineral water', 'whole wheat rice'],
#  ['burgers', 'olive oil', 'nan'],
#  ['burgers', 'nan', 'pancakes'],
#  ['burgers', 'red wine', 'nan'],
#  ['burgers', 'salmon', 'nan'],
#  ['burgers', 'nan', 'shrimp'],
#  ['burgers', 'soup', 'nan'],
#  ['burgers', 'spaghetti', 'nan'],
#  ['burgers', 'tomato juice', 'nan'],
#  ['burgers', 'nan', 'tomatoes'],
#  ['burgers', 'turkey', 'nan'],
#  ['burgers', 'whole wheat pasta', 'nan'],
#  ['burgers', 'whole wheat rice', 'nan'],
#  ['burgers', 'spaghetti', 'pancakes'],
#  ['burgers', 'spaghetti', 'turkey'],
#  ['burgers', 'spaghetti', 'whole wheat rice'],
#  ['nan', 'chicken', 'butter'],
#  ['nan', 'butter', 'chocolate'],
#  ['nan', 'butter', 'cooking oil'],
#  ['eggs', 'nan', 'butter'],
#  ['french fries', 'nan', 'butter'],
#  ['nan', 'frozen vegetables', 'butter'],
#  ['grated cheese', 'nan', 'butter'],
#  ['nan', 'butter', 'green tea'],
#  ['nan', 'ground beef', 'butter'],
#  ['nan', 'butter', 'low fat yogurt'],
#  ['milk', 'nan', 'butter'],
#  ['mineral water', 'nan', 'butter'],
#  ['nan', 'butter', 'pancakes'],
#  ['nan', 'butter', 'shrimp'],
#  ['spaghetti', 'nan', 'butter'],
#  ['nan', 'butter', 'tomatoes'],
#  ['whole wheat rice', 'nan', 'butter'],
#  ['cake', 'nan', 'cereals'],
#  ['cake', 'chicken', 'mineral water'],
#  ['cake', 'chicken', 'nan'],
#  ['eggs', 'cake', 'chocolate'],
#  ['cake', 'french fries', 'chocolate'],
#  ['cake', 'chocolate', 'milk'],
#  ['cake', 'mineral water', 'chocolate'],
#  ['cake', 'nan', 'chocolate'],
#  ['cake', 'spaghetti', 'chocolate'],
#  ['cake', 'nan', 'cookies'],
#  ['cake', 'nan', 'cooking oil'],
#  ['cottage cheese', 'cake', 'nan'],
#  ['eggs', 'cake', 'french fries'],
#  ['eggs', 'cake', 'green tea'],
#  ['eggs', 'cake', 'milk'],
#  ['eggs', 'cake', 'mineral water'],
#  ['eggs', 'cake', 'nan'],
#  ['eggs', 'cake', 'pancakes'],
#  ['eggs', 'cake', 'spaghetti'],
#  ['eggs', 'cake', 'turkey'],
#  ['cake', 'nan', 'energy bar'],
#  ['cake', 'energy drink', 'nan'],
#  ['cake', 'nan', 'escalope'],
#  ['cake', 'french fries', 'green tea'],
#  ['cake', 'french fries', 'milk'],
#  ['cake', 'french fries', 'mineral water'],
#  ['cake', 'french fries', 'nan'],
#  ['cake', 'french fries', 'spaghetti'],
#  ['fresh bread', 'cake', 'nan'],
#  ['cake', 'nan', 'fresh tuna'],
#  ['cake', 'mineral water', 'frozen smoothie'],
#  ['cake', 'nan', 'frozen smoothie'],
#  ['cake', 'mineral water', 'frozen vegetables'],
#  ['cake', 'nan', 'frozen vegetables'],
#  ['cake', 'frozen vegetables', 'spaghetti'],
#  ['cake', 'frozen vegetables', 'tomatoes'],
#  ['grated cheese', 'cake', 'nan'],
#  ['cake', 'mineral water', 'green tea'],
#  ['cake', 'nan', 'green tea'],
#  ['pancakes', 'cake', 'green tea'],
#  ['cake', 'ground beef', 'mineral water'],
#  ['cake', 'ground beef', 'nan'],
#  ['cake', 'ground beef', 'spaghetti'],
#  ['cake', 'nan', 'herb & pepper'],
#  ['cake', 'nan', 'honey'],
#  ['hot dogs', 'cake', 'nan'],
#  ['cake', 'nan', 'low fat yogurt'],
#  ['cake', 'mineral water', 'milk'],
#  ['cake', 'nan', 'milk'],
#  ['cake', 'spaghetti', 'milk'],
#  ['cake', 'mineral water', 'nan'],
#  ['cake', 'olive oil', 'mineral water'],
#  ['cake', 'mineral water', 'pancakes'],
#  ['soup', 'cake', 'mineral water'],
#  ['cake', 'mineral water', 'spaghetti'],
#  ['cake', 'mineral water', 'tomatoes'],
#  ['cake', 'whole wheat rice', 'mineral water'],
#  ['cake', 'olive oil', 'nan'],
#  ['cake', 'nan', 'pancakes'],
#  ['cake', 'nan', 'parmesan cheese'],
#  ['cake', 'red wine', 'nan'],
#  ['cake', 'salmon', 'nan'],
#  ['cake', 'nan', 'shrimp'],
#  ['soup', 'cake', 'nan'],
#  ['cake', 'nan', 'spaghetti'],
#  ['cake', 'tomato juice', 'nan'],
#  ['cake', 'nan', 'tomatoes'],
#  ['cake', 'turkey', 'nan'],
#  ['cake', 'whole wheat pasta', 'nan'],
#  ['cake', 'whole wheat rice', 'nan'],
#  ['cake', 'olive oil', 'spaghetti'],
#  ['cake', 'spaghetti', 'pancakes'],
#  ['cake', 'spaghetti', 'tomatoes'],
#  ['carrots', 'nan', 'chocolate'],
#  ['carrots', 'nan', 'green tea'],
#  ['mineral water', 'carrots', 'nan'],
#  ['spaghetti', 'carrots', 'nan'],
#  ['cereals', 'nan', 'chocolate'],
#  ['eggs', 'cereals', 'nan'],
#  ['cereals', 'french fries', 'nan'],
#  ['cereals', 'nan', 'frozen vegetables'],
#  ['cereals', 'nan', 'green tea'],
#  ['cereals', 'ground beef', 'nan'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['cereals', 'nan', 'herb & pepper'],
#  ['cereals', 'mineral water', 'milk'],
#  ['cereals', 'nan', 'milk'],
#  ['cereals', 'mineral water', 'nan'],
#  ['cereals', 'mineral water', 'spaghetti'],
#  ['cereals', 'nan', 'pancakes'],
#  ['cereals', 'nan', 'shrimp'],
#  ['cereals', 'nan', 'spaghetti'],
#  ['chocolate', 'nan', 'champagne'],
#  ['nan', 'cookies', 'champagne'],
#  ['eggs', 'nan', 'champagne'],
#  ['nan', 'escalope', 'champagne'],
#  ['french fries', 'nan', 'champagne'],
#  ['frozen smoothie', 'nan', 'champagne'],
#  ['nan', 'frozen vegetables', 'champagne'],
#  ['nan', 'green tea', 'champagne'],
#  ['ground beef', 'nan', 'champagne'],
#  ['nan', 'champagne', 'low fat yogurt'],
#  ['milk', 'nan', 'champagne'],
#  ['mineral water', 'nan', 'champagne'],
#  ['pancakes', 'nan', 'champagne'],
#  ['spaghetti', 'nan', 'champagne'],
#  ['whole wheat rice', 'nan', 'champagne'],
#  ['eggs', 'chicken', 'chocolate'],
#  ['french fries', 'chicken', 'chocolate'],
#  ['chicken', 'green tea', 'chocolate'],
#  ['milk', 'chicken', 'chocolate'],
#  ['mineral water', 'chicken', 'chocolate'],
#  ['chicken', 'nan', 'chocolate'],
#  ['spaghetti', 'chicken', 'chocolate'],
#  ['chicken', 'nan', 'cooking oil'],
#  ['cottage cheese', 'chicken', 'nan'],
#  ['eggs', 'french fries', 'chicken'],
#  ['eggs', 'milk', 'chicken'],
#  ['eggs', 'mineral water', 'chicken'],
#  ['eggs', 'chicken', 'nan'],
#  ['eggs', 'spaghetti', 'chicken'],
#  ['chicken', 'nan', 'escalope'],
#  ['milk', 'french fries', 'chicken'],
#  ['mineral water', 'french fries', 'chicken'],
#  ['french fries', 'chicken', 'nan'],
#  ['spaghetti', 'french fries', 'chicken'],
#  ['fresh bread', 'chicken', 'nan'],
#  ['chicken', 'nan', 'frozen smoothie'],
#  ['mineral water', 'chicken', 'frozen vegetables'],
#  ['nan', 'chicken', 'frozen vegetables'],
#  ['spaghetti', 'chicken', 'frozen vegetables'],
#  ['grated cheese', 'chicken', 'nan'],
#  ['mineral water', 'chicken', 'green tea'],
#  ['chicken', 'nan', 'green tea'],
#  ['spaghetti', 'chicken', 'green tea'],
#  ['milk', 'chicken', 'ground beef'],
#  ['mineral water', 'chicken', 'ground beef'],
#  ['chicken', 'ground beef', 'nan'],
#  ['spaghetti', 'chicken', 'ground beef'],
#  ['chicken', 'nan', 'herb & pepper'],
#  ['nan', 'chicken', 'honey'],
#  ['hot dogs', 'chicken', 'nan'],
#  ['nan', 'chicken', 'light cream'],
#  ['chicken', 'nan', 'low fat yogurt'],
#  ['meatballs', 'chicken', 'nan'],
#  ['milk', 'chicken', 'mineral water'],
#  ['milk', 'chicken', 'nan'],
#  ['milk', 'chicken', 'olive oil'],
#  ['milk', 'chicken', 'pancakes'],
#  ['milk', 'chicken', 'spaghetti'],
#  ['mineral water', 'chicken', 'nan'],
#  ['mineral water', 'chicken', 'olive oil'],
#  ['mineral water', 'chicken', 'pancakes'],
#  ['soup', 'mineral water', 'chicken'],
#  ['mineral water', 'chicken', 'spaghetti'],
#  ['mineral water', 'chicken', 'tomatoes'],
#  ['olive oil', 'chicken', 'nan'],
#  ['chicken', 'nan', 'pancakes'],
#  ['chicken', 'salmon', 'nan'],
#  ['chicken', 'nan', 'shrimp'],
#  ['soup', 'chicken', 'nan'],
#  ['spaghetti', 'chicken', 'nan'],
#  ['tomato juice', 'chicken', 'nan'],
#  ['chicken', 'nan', 'tomatoes'],
#  ['turkey', 'chicken', 'nan'],
#  ['chicken', 'whole wheat pasta', 'nan'],
#  ['whole wheat rice', 'chicken', 'nan'],
#  ['olive oil', 'chicken', 'spaghetti'],
#  ['spaghetti', 'chicken', 'pancakes'],
#  ['french fries', 'cookies', 'chocolate'],
#  ['nan', 'cookies', 'chocolate'],
#  ['spaghetti', 'cookies', 'chocolate'],
#  ['eggs', 'cooking oil', 'chocolate'],
#  ['milk', 'cooking oil', 'chocolate'],
#  ['mineral water', 'cooking oil', 'chocolate'],
#  ['cooking oil', 'nan', 'chocolate'],
#  ['spaghetti', 'cooking oil', 'chocolate'],
#  ['cottage cheese', 'nan', 'chocolate'],
#  ['eggs', 'escalope', 'chocolate'],
#  ['eggs', 'french fries', 'chocolate'],
#  ['eggs', 'frozen vegetables', 'chocolate'],
#  ['eggs', 'green tea', 'chocolate'],
#  ['eggs', 'ground beef', 'chocolate'],
#  ['eggs', 'chocolate', 'low fat yogurt'],
#  ['eggs', 'milk', 'chocolate'],
#  ['eggs', 'mineral water', 'chocolate'],
#  ['eggs', 'nan', 'chocolate'],
#  ['eggs', 'olive oil', 'chocolate'],
#  ['eggs', 'pancakes', 'chocolate'],
#  ['eggs', 'shrimp', 'chocolate'],
#  ['eggs', 'spaghetti', 'chocolate'],
#  ['eggs', 'turkey', 'chocolate'],
#  ['energy bar', 'nan', 'chocolate'],
#  ['energy drink', 'nan', 'chocolate'],
#  ['french fries', 'escalope', 'chocolate'],
#  ['milk', 'escalope', 'chocolate'],
#  ['mineral water', 'escalope', 'chocolate'],
#  ['nan', 'escalope', 'chocolate'],
#  ['spaghetti', 'escalope', 'chocolate'],
#  ['frozen smoothie', 'french fries', 'chocolate'],
#  ['french fries', 'frozen vegetables', 'chocolate'],
#  ['grated cheese', 'french fries', 'chocolate'],
#  ['french fries', 'green tea', 'chocolate'],
#  ['french fries', 'ground beef', 'chocolate'],
#  ['french fries', 'chocolate', 'low fat yogurt'],
#  ['milk', 'french fries', 'chocolate'],
#  ['mineral water', 'french fries', 'chocolate'],
#  ['french fries', 'nan', 'chocolate'],
#  ['olive oil', 'french fries', 'chocolate'],
#  ['pancakes', 'french fries', 'chocolate'],
#  ['french fries', 'shrimp', 'chocolate'],
#  ['spaghetti', 'french fries', 'chocolate'],
#  ['french fries', 'chocolate', 'tomatoes'],
#  ['french wine', 'nan', 'chocolate'],
#  ['fresh bread', 'mineral water', 'chocolate'],
#  ['fresh bread', 'nan', 'chocolate'],
#  ['fresh tuna', 'nan', 'chocolate'],
#  ['nan', 'fromage blanc', 'chocolate'],
#  ['frozen smoothie', 'chocolate', 'milk'],
#  ['frozen smoothie', 'mineral water', 'chocolate'],
#  ['frozen smoothie', 'nan', 'chocolate'],
#  ['frozen smoothie', 'spaghetti', 'chocolate'],
#  ['green tea', 'frozen vegetables', 'chocolate'],
#  ['ground beef', 'frozen vegetables', 'chocolate'],
#  ['milk', 'frozen vegetables', 'chocolate'],
#  ['mineral water', 'frozen vegetables', 'chocolate'],
#  ['nan', 'frozen vegetables', 'chocolate'],
#  ['olive oil', 'frozen vegetables', 'chocolate'],
#  ['pancakes', 'frozen vegetables', 'chocolate'],
#  ['shrimp', 'frozen vegetables', 'chocolate'],
#  ['spaghetti', 'frozen vegetables', 'chocolate'],
#  ['frozen vegetables', 'chocolate', 'tomatoes'],
#  ['grated cheese', 'mineral water', 'chocolate'],
#  ['grated cheese', 'nan', 'chocolate'],
#  ['grated cheese', 'spaghetti', 'chocolate'],
#  ['ground beef', 'green tea', 'chocolate'],
#  ['milk', 'green tea', 'chocolate'],
#  ['mineral water', 'green tea', 'chocolate'],
#  ['nan', 'green tea', 'chocolate'],
#  ['pancakes', 'green tea', 'chocolate'],
#  ['spaghetti', 'green tea', 'chocolate'],
#  ['ground beef', 'chocolate', 'herb & pepper'],
#  ['milk', 'ground beef', 'chocolate'],
#  ['mineral water', 'ground beef', 'chocolate'],
#  ['ground beef', 'nan', 'chocolate'],
#  ['olive oil', 'ground beef', 'chocolate'],
#  ['pancakes', 'ground beef', 'chocolate'],
#  ['ground beef', 'shrimp', 'chocolate'],
#  ['spaghetti', 'ground beef', 'chocolate'],
#  ['ham', 'nan', 'chocolate'],
#  ['mineral water', 'chocolate', 'herb & pepper'],
#  ['nan', 'chocolate', 'herb & pepper'],
#  ['mineral water', 'honey', 'chocolate'],
#  ['nan', 'honey', 'chocolate'],
#  ['hot dogs', 'nan', 'chocolate'],
#  ['nan', 'light cream', 'chocolate'],
#  ['light mayo', 'nan', 'chocolate'],
#  ['milk', 'chocolate', 'low fat yogurt'],
#  ['mineral water', 'chocolate', 'low fat yogurt'],
#  ['nan', 'chocolate', 'low fat yogurt'],
#  ['spaghetti', 'chocolate', 'low fat yogurt'],
#  ['milk', 'mineral water', 'chocolate'],
#  ['milk', 'nan', 'chocolate'],
#  ['milk', 'olive oil', 'chocolate'],
#  ['pancakes', 'milk', 'chocolate'],
#  ['milk', 'shrimp', 'chocolate'],
#  ['soup', 'milk', 'chocolate'],
#  ['milk', 'spaghetti', 'chocolate'],
#  ['milk', 'chocolate', 'tomatoes'],
#  ['milk', 'turkey', 'chocolate'],
#  ['mineral water', 'nan', 'chocolate'],
#  ['mineral water', 'olive oil', 'chocolate'],
#  ['pancakes', 'mineral water', 'chocolate'],
#  ['mineral water', 'salmon', 'chocolate'],
#  ['mineral water', 'shrimp', 'chocolate'],
#  ['soup', 'mineral water', 'chocolate'],
#  ['mineral water', 'spaghetti', 'chocolate'],
#  ['mineral water', 'chocolate', 'tomatoes'],
#  ['mineral water', 'turkey', 'chocolate'],
#  ['mineral water', 'whole wheat rice', 'chocolate'],
#  ['nan', 'chocolate', 'mint'],
#  ['muffins', 'nan', 'chocolate'],
#  ['mushroom cream sauce', 'nan', 'chocolate'],
#  ['oil', 'nan', 'chocolate'],
#  ['olive oil', 'nan', 'chocolate'],
#  ['pancakes', 'nan', 'chocolate'],
#  ['parmesan cheese', 'nan', 'chocolate'],
#  ['pepper', 'nan', 'chocolate'],
#  ['protein bar', 'nan', 'chocolate'],
#  ['red wine', 'nan', 'chocolate'],
#  ['rice', 'nan', 'chocolate'],
#  ['salmon', 'nan', 'chocolate'],
#  ['shrimp', 'nan', 'chocolate'],
#  ['soup', 'nan', 'chocolate'],
#  ['spaghetti', 'nan', 'chocolate'],
#  ['strawberries', 'nan', 'chocolate'],
#  ['tomato juice', 'nan', 'chocolate'],
#  ['tomato sauce', 'nan', 'chocolate'],
#  ['nan', 'chocolate', 'tomatoes'],
#  ['turkey', 'nan', 'chocolate'],
#  ['vegetables mix', 'nan', 'chocolate'],
#  ['white wine', 'nan', 'chocolate'],
#  ['whole wheat pasta', 'nan', 'chocolate'],
#  ['whole wheat rice', 'nan', 'chocolate'],
#  ['yogurt cake', 'nan', 'chocolate'],
#  ['pancakes', 'olive oil', 'chocolate'],
#  ['olive oil', 'spaghetti', 'chocolate'],
#  ['pancakes', 'spaghetti', 'chocolate'],
#  ['spaghetti', 'salmon', 'chocolate'],
#  ['spaghetti', 'shrimp', 'chocolate'],
#  ['soup', 'spaghetti', 'chocolate'],
#  ['spaghetti', 'chocolate', 'tomatoes'],
#  ['spaghetti', 'turkey', 'chocolate'],
#  ['spaghetti', 'whole wheat rice', 'chocolate'],
#  ['eggs', 'cider', 'nan'],
#  ['milk', 'cider', 'nan'],
#  ['eggs', 'nan', 'cookies'],
#  ['french fries', 'cookies', 'green tea'],
#  ['french fries', 'nan', 'cookies'],
#  ['nan', 'cookies', 'frozen smoothie'],
#  ['nan', 'cookies', 'green tea'],
#  ['nan', 'ground beef', 'cookies'],
#  ['nan', 'cookies', 'low fat yogurt'],
#  ['milk', 'nan', 'cookies'],
#  ['mineral water', 'nan', 'cookies'],
#  ['nan', 'cookies', 'pancakes'],
#  ['nan', 'cookies', 'shrimp'],
#  ['spaghetti', 'nan', 'cookies'],
#  ['whole wheat rice', 'nan', 'cookies'],
#  ['eggs', 'milk', 'cooking oil'],
#  ['eggs', 'mineral water', 'cooking oil'],
#  ['eggs', 'nan', 'cooking oil'],
#  ['eggs', 'spaghetti', 'cooking oil'],
#  ['nan', 'escalope', 'cooking oil'],
#  ['french fries', 'nan', 'cooking oil'],
#  ['frozen smoothie', 'nan', 'cooking oil'],
#  ['nan', 'frozen vegetables', 'cooking oil'],
#  ['grated cheese', 'nan', 'cooking oil'],
#  ['mineral water', 'green tea', 'cooking oil'],
#  ['nan', 'green tea', 'cooking oil'],
#  ['mineral water', 'ground beef', 'cooking oil'],
#  ['ground beef', 'nan', 'cooking oil'],
#  ['spaghetti', 'ground beef', 'cooking oil'],
#  ['nan', 'cooking oil', 'herb & pepper'],
#  ['nan', 'honey', 'cooking oil'],
#  ['nan', 'cooking oil', 'low fat yogurt'],
#  ['milk', 'mineral water', 'cooking oil'],
#  ['milk', 'nan', 'cooking oil'],
#  ['milk', 'spaghetti', 'cooking oil'],
#  ['mineral water', 'nan', 'cooking oil'],
#  ['pancakes', 'mineral water', 'cooking oil'],
#  ['mineral water', 'spaghetti', 'cooking oil'],
#  ['olive oil', 'nan', 'cooking oil'],
#  ['pancakes', 'nan', 'cooking oil'],
#  ['salmon', 'nan', 'cooking oil'],
#  ['shrimp', 'nan', 'cooking oil'],
#  ['soup', 'nan', 'cooking oil'],
#  ['spaghetti', 'nan', 'cooking oil'],
#  ['nan', 'cooking oil', 'tomatoes'],
#  ['turkey', 'nan', 'cooking oil'],
#  ['whole wheat rice', 'nan', 'cooking oil'],
#  ['cottage cheese', 'eggs', 'nan'],
#  ['cottage cheese', 'french fries', 'nan'],
#  ['cottage cheese', 'nan', 'frozen smoothie'],
#  ['cottage cheese', 'nan', 'frozen vegetables'],
#  ['cottage cheese', 'nan', 'green tea'],
#  ['cottage cheese', 'ground beef', 'nan'],
#  ['cottage cheese', 'milk', 'nan'],
#  ['cottage cheese', 'mineral water', 'nan'],
#  ['cottage cheese', 'mineral water', 'spaghetti'],
#  ['cottage cheese', 'olive oil', 'nan'],
#  ['cottage cheese', 'nan', 'pancakes'],
#  ['cottage cheese', 'spaghetti', 'nan'],
#  ['eggs', 'eggplant', 'nan'],
#  ['mineral water', 'eggplant', 'nan'],
#  ['spaghetti', 'eggplant', 'nan'],
#  ['eggs', 'energy bar', 'nan'],
#  ['eggs', 'energy drink', 'nan'],
#  ['eggs', 'mineral water', 'escalope'],
#  ['eggs', 'nan', 'escalope'],
#  ['eggs', 'french fries', 'frozen vegetables'],
#  ['eggs', 'french fries', 'green tea'],
#  ['eggs', 'french fries', 'ground beef'],
#  ['eggs', 'french fries', 'low fat yogurt'],
#  ['eggs', 'milk', 'french fries'],
#  ['eggs', 'mineral water', 'french fries'],
#  ['eggs', 'french fries', 'nan'],
#  ['eggs', 'french fries', 'pancakes'],
#  ['eggs', 'spaghetti', 'french fries'],
#  ['eggs', 'french fries', 'tomatoes'],
#  ['eggs', 'french fries', 'turkey'],
#  ['eggs', 'french wine', 'nan'],
#  ['eggs', 'fresh bread', 'mineral water'],
#  ['eggs', 'fresh bread', 'nan'],
#  ['eggs', 'nan', 'fresh tuna'],
#  ['eggs', 'nan', 'fromage blanc'],
#  ['eggs', 'mineral water', 'frozen smoothie'],
#  ['eggs', 'nan', 'frozen smoothie'],
#  ['eggs', 'frozen vegetables', 'green tea'],
#  ['eggs', 'ground beef', 'frozen vegetables'],
#  ['eggs', 'frozen vegetables', 'low fat yogurt'],
#  ['eggs', 'milk', 'frozen vegetables'],
#  ['eggs', 'mineral water', 'frozen vegetables'],
#  ['eggs', 'nan', 'frozen vegetables'],
#  ['eggs', 'frozen vegetables', 'pancakes'],
#  ['eggs', 'frozen vegetables', 'shrimp'],
#  ['eggs', 'spaghetti', 'frozen vegetables'],
#  ['eggs', 'frozen vegetables', 'tomatoes'],
#  ['eggs', 'grated cheese', 'mineral water'],
#  ['eggs', 'grated cheese', 'nan'],
#  ['eggs', 'grated cheese', 'spaghetti'],
#  ['eggs', 'milk', 'green tea'],
#  ['eggs', 'mineral water', 'green tea'],
#  ['eggs', 'nan', 'green tea'],
#  ['eggs', 'pancakes', 'green tea'],
#  ['eggs', 'spaghetti', 'green tea'],
#  ['eggs', 'turkey', 'green tea'],
#  ['eggs', 'ground beef', 'herb & pepper'],
#  ['eggs', 'milk', 'ground beef'],
#  ['eggs', 'mineral water', 'ground beef'],
#  ['eggs', 'ground beef', 'nan'],
#  ['eggs', 'spaghetti', 'ground beef'],
#  ['eggs', 'nan', 'ham'],
#  ['eggs', 'milk', 'herb & pepper'],
#  ['eggs', 'mineral water', 'herb & pepper'],
#  ['eggs', 'nan', 'herb & pepper'],
#  ['eggs', 'spaghetti', 'herb & pepper'],
#  ['eggs', 'nan', 'honey'],
#  ['eggs', 'hot dogs', 'nan'],
#  ['eggs', 'nan', 'light cream'],
#  ['eggs', 'nan', 'light mayo'],
#  ['eggs', 'milk', 'low fat yogurt'],
#  ['eggs', 'mineral water', 'low fat yogurt'],
#  ['eggs', 'nan', 'low fat yogurt'],
#  ['eggs', 'spaghetti', 'low fat yogurt'],
#  ...]
