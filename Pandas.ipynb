# %%
# Pandas -->
#         It is an open source library that is used for handle data manipulation

# %%
# Data structure of Pandas -->
# 1> Series -- It is one-dimension array. It contain only values not column name.
# 2> Dataframe-- It is multi-dimension array. It contain values with column name.

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# series--
a=pd.Series([1,45,78,90])
a
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# Dataframe
a={
    "Emp_ID" : [1,2,3,4,5,6,7,8],
    "Name" : ["Sam","Raj","Nidhi","Ankit","Sam","Gravit","Pallavi","Sam"],
    "Department" : ["IT","Sales","IT","IT","Operations","IT","Sales","IT"],
    "Working_hours" : [8,9,9,9,8,9,8,8]
}

# %%
type(a)
# Out:
# dict

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2      Raj       Sales              9
# 2       3    Nidhi          IT              9
# 3       4    Ankit          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
# How can we import or export our dataframe ?

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df1.to_csv("/content/sample_data/new_test.csv")

# %%
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2      Raj       Sales              9
# 2       3    Nidhi          IT              9
# 3       4    Ankit          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
# How can we check top 5 data?
df.head()
# Out:
#    Emp_ID   Name  Department  Working_hours
# 0       1    Sam          IT              8
# 1       2    Raj       Sales              9
# 2       3  Nidhi          IT              9
# 3       4  Ankit          IT              9
# 4       5    Sam  Operations              8

# %%
df.head(2)
# Out:
#    Emp_ID Name Department  Working_hours
# 0       1  Sam         IT              8
# 1       2  Raj      Sales              9

# %%
# How can we check bottom data ?
df.tail()
# Out:
#    Emp_ID     Name  Department  Working_hours
# 3       4    Ankit          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
df1.tail(3)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
# How can we check random indexed data ?
df.sample(3)
# Out:
#    Emp_ID   Name  Department  Working_hours
# 3       4  Ankit          IT              9
# 2       3  Nidhi          IT              9
# 4       5    Sam  Operations              8

# %%
# How can we check total shape of data ?
df.shape
# Out:
# (8, 4)

# %%
# How can we check total columns in a data frames ?
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Working_hours'], dtype='object')

# %%
# Case 1
# You have to update 'Aniket' to 'Yamini' and 'Raj' to 'Rajat' and change working hours also

# %%
df['Name']
# Out:
# 0        Sam
# 1        Raj
# 2      Nidhi
# 3      Ankit
# 4        Sam
# 5     Gravit
# 6    Pallavi
# 7        Sam
# Name: Name, dtype: object

# %%
df['Name'][1] = 'Rajat'
df['Name'][3]='Yamini'
# Out:
# <ipython-input-30-1ba4f191f16d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][1] = 'Rajat'
# <ipython-input-30-1ba4f191f16d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][3]='Yamini'

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales              9
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
df['Working_hours'][1]=10
# Out:
# <ipython-input-33-f24dc661c702>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Working_hours'][1]=10
# <ipython-input-33-f24dc661c702>:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
# How can we check total sub_categories frequency of a columns?

# %%
df['Name'].value_counts()
# Out:
# Name
# Sam        3
# Rajat      1
# Nidhi      1
# Yamini     1
# Gravit     1
# Pallavi    1
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# IT            5
# Sales         2
# Operations    1
# Name: count, dtype: int64

# %%
# How can We handle missing data ?

# %%
df.isnull().sum()
# Out:
# Emp_ID           0
# Name             0
# Department       0
# Working_hours    0
# dtype: int64

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3    Nidhi          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit          IT              9
# 6       7  Pallavi       Sales              8
# 7       8      Sam          IT              8

# %%
df['Name'][2]=None
df['Department'][5]=None
df['Department'][6]=None
# Out:
# <ipython-input-42-8f22085265c2>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Name'][2]=None
# <ipython-input-42-8f22085265c2>:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#    Emp_ID     Name  Department  Working_hours
# 0       1      Sam          IT              8
# 1       2    Rajat       Sales             10
# 2       3     None          IT              9
# 3       4   Yamini          IT              9
# 4       5      Sam  Operations              8
# 5       6   Gravit        None              9
# 6       7  Pallavi        None              8
# 7       8      Sam          IT              8

# %%
df.isnull().sum()  # isnull to find null value
# Out:
# Emp_ID           0
# Name             1
# Department       2
# Working_hours    0
# dtype: int64

# %%
df4=df.dropna()   # dropna to remove missing value

# %%
df4
# Out:
#    Emp_ID    Name  Department  Working_hours
# 0       1     Sam          IT              8
# 1       2   Rajat       Sales             10
# 3       4  Yamini          IT              9
# 4       5     Sam  Operations              8
# 7       8     Sam          IT              8
