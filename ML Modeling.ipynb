# %%
# ML Modeling
# Data
# 1> Numerical
# 2> Categorical

# Model -->
# 1> Supervised  --Label data given
# 2> Unsupervised -- Unlabelled data given

# %% [markdown]
# ## ***1> Supervised ML Modeling ***

# %%
#  data  -- x, y
# y -->
# 1> Continuous--> Linear Regression , DecisionTreeRegression , RandomForestRegressor
# 2> Discrete--> LogisticRegression , DecisionTreeClassifier , RandomForestClassifier

# %% [markdown]
# # ***1> Linear Regression***

# %%
# df --> x , y
# x -- > x_train , x_test
# y -- > y_train , y_test
# model(x_train , y_train)
# model(x_test) --> output ?? --> y_pred
# Actual output  == y_test
# check differnce (y_pred , y_test)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/insurance.csv')

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker']=lb.fit_transform(df['smoker'])
df['region']=lb.fit_transform(df['region'])

# %%
df.sample(5)
# Out:
#       age  sex    bmi  children  smoker  region      charges
# 53     36    1  34.43         0       1       2  37742.57570
# 891    36    0  29.04         4       0       2   7243.81360
# 1286   28    0  17.29         0       0       0   3732.62510
# 925    50    1  32.11         2       0       0  25333.33284
# 1312   34    1  42.90         1       0       3   4536.25900

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,
                                                     random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
# lr = LinearRegression(fit_intercept=False , n_jobs = 10 , positive = True)

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 8924.40724442,  7116.29501758, 36909.01352144,  9507.87469118,
#        27013.3500079 , 10790.77956153,   226.29844571, 16942.71599941,
#         1056.63079407, 11267.91997309, 28048.59793155,  9424.36324087,
#         5326.32232088, 38460.06017922, 40303.40597026, 37147.01010262,
#        15287.91876684, 35965.05485917,  9179.1753067 , 31510.8319849 ,
#         3797.79068365, 10070.82803304,  2312.57551348,  7074.41348194,
#        11352.37224357, 12907.77079523, 14448.84678727,  6205.65997921,
#         9917.00839638,  2239.50032819,  9060.55469043, 13120.56214535,
#         4617.70702822,  3467.91218926,  4402.74821855, 12967.91608907,
#         1927.44498944,  8757.9180081 , 33324.35180597, 32638.47697026,
#         3852.41756615,  4370.39670883, 14080.76023234, 11478.63402576,
#         8829.26135924, 12046.15119133,  5322.80515731,  3100.71182484,
#        35546.60547574,  9201.61196817, 15894.23763341,  2406.04003607,
# ...

# %%
from sklearn.metrics import r2_score

# %%
# r2_score -- regression matrics that check model kitna train hua  -- accuracy

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7833463107364539
