# %%
import pandas as pd

# %%
df1 = pd.read_csv("//content//covid_toy.csv")

# %%
df1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df1.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df = pd.read_csv("//content//placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail(5)
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe() # statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()  # data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4 , :3] #iloc[row_range, col_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3, ['cgpa' , 'placed']] # loc[row_range,col_name]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
df.shape
# Out:
# (100, 3)

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty # it return true if there any missing data in dataframe otherwise false
b
# Out:
# False

# %%
df.isnull().sum() # for checking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna() # for remove missing rows
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i=df.ndim #number of axes(it is 2)
i
# Out:
# 2

# %%
t = df.shape  #shape=n(row),n(col)
t
# Out:
# (100, 3)

# %%
d =df.size  # n(rows)
d
# Out:
# 300

# %%
a=df.values # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
p=df

# %%
p
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p['cgpa']=p['cgpa'].astype(int)

# %%
p
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
p['resume_score']=p['resume_score'].astype(int)

# %%
p
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
# Add
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     16             6       1
# 1     14             5       0
# 2     16             8       1
# 3     14             7       1
# 4     15             7       1
# ..   ...           ...     ...
# 95    14             6       0
# 96    16             7       1
# 97    14             7       0
# 98    16             5       1
# 99    14             6       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']=df['resume_score'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     16            10       1
# 1     14             9       0
# 2     16            12       1
# 3     14            11       1
# 4     15            11       1
# ..   ...           ...     ...
# 95    14            10       0
# 96    16            11       1
# 97    14            11       0
# 98    16             9       1
# 99    14            10       0
#
# [100 rows x 3 columns]

# %%
df['placed']=df['placed'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     16            10       5
# 1     14             9       4
# 2     16            12       5
# 3     14            11       5
# 4     15            11       5
# ..   ...           ...     ...
# 95    14            10       4
# 96    16            11       5
# 97    14            11       4
# 98    16             9       5
# 99    14            10       4
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()
p
# Out:
# cgpa            17
# resume_score    13
# placed           5
# dtype: int64

# %%
q=df.min()
q
# Out:
# cgpa            13
# resume_score     8
# placed           4
# dtype: int64

# %%
r = df['cgpa'].mean()
r
# Out:
# 14.47

# %%
s = df['cgpa'].median()
s
# Out:
# 14.0

# %%
g= df.filter(items = ['cgpa','placed'])
g
df[['cgpa','placed']]  # second option of filtering
# Out:
#     cgpa  placed
# 0     16       5
# 1     14       4
# 2     16       5
# 3     14       5
# 4     15       5
# ..   ...     ...
# 95    14       4
# 96    16       5
# 97    14       4
# 98    16       5
# 99    14       4
#
# [100 rows x 2 columns]

# %%
a = df.filter(items = [3,4,5,6], axis=0) # axis = 0 means row wise operation
a
# Out:
#    cgpa  resume_score  placed
# 3    14            11       5
# 4    15            11       5
# 5    16            10       5
# 6    13            11       4

# %%
# how to rename a column
p = df.rename(columns = {'cgpa':'updated_cgpa','resume_score':'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             16              10       5
# 1             14               9       4
# 2             16              12       5
# 3             14              11       5
# 4             15              11       5
# ..           ...             ...     ...
# 95            14              10       4
# 96            16              11       5
# 97            14              11       4
# 98            16               9       5
# 99            14              10       4
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     16            10       5
# 1     14             9       4
# 2     16            12       5
# 3     14            11       5
# 4     15            11       5
# ..   ...           ...     ...
# 95    14            10       4
# 96    16            11       5
# 97    14            11       4
# 98    16             9       5
# 99    14            10       4
#
# [100 rows x 3 columns]

# %%
df['half']=df['cgpa'].where(df['cgpa']>15,other = 0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    16            10       5    16
# 1    14             9       4     0
# 2    16            12       5    16
# 3    14            11       5     0
# 4    15            11       5     0
# 5    16            10       5    16
# 6    13            11       4     0
# 7    14            10       4     0
# 8    14            10       4     0
# 9    15            11       5     0

# %%
df = pd.read_csv("//content//covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({"Female":0 , "Male":1 })

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60       1  103.0    Mild    Kolkata        No
# 1    27       1  100.0    Mild      Delhi       Yes
# 2    42       1  101.0    Mild      Delhi        No
# 3    31       0   98.0    Mild    Kolkata        No
# 4    65       0  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12       0  104.0    Mild  Bangalore        No
# 96   51       0  101.0  Strong    Kolkata       Yes
# 97   20       0  101.0    Mild  Bangalore        No
# 98    5       0   98.0  Strong     Mumbai        No
# 99   10       0   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['cough'] = df['cough'].map({"Mild":0 , "Strong":1 })

# %%
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    60       1  103.0      0    Kolkata        No
# 1    27       1  100.0      0      Delhi       Yes
# 2    42       1  101.0      0      Delhi        No
# 3    31       0   98.0      0    Kolkata        No
# 4    65       0  101.0      0     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   12       0  104.0      0  Bangalore        No
# 96   51       0  101.0      1    Kolkata       Yes
# 97   20       0  101.0      0  Bangalore        No
# 98    5       0   98.0      1     Mumbai        No
# 99   10       0   98.0      1    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['has_covid'] = df['has_covid'].map({"No":0 , "Yes":1 })

# %%
df
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  103.0      0    Kolkata          0
# 1    27       1  100.0      0      Delhi          1
# 2    42       1  101.0      0      Delhi          0
# 3    31       0   98.0      0    Kolkata          0
# 4    65       0  101.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  104.0      0  Bangalore          0
# 96   51       0  101.0      1    Kolkata          1
# 97   20       0  101.0      0  Bangalore          0
# 98    5       0   98.0      1     Mumbai          0
# 99   10       0   98.0      1    Kolkata          1
#
# [100 rows x 6 columns]

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# age            int64
# gender         int64
# fever        float64
# cough          int64
# city          object
# has_covid      int64
# dtype: object

# %%
df.describe()
# Out:
#               age      gender       fever       cough  has_covid
# count  100.000000  100.000000   90.000000  100.000000     100.00
# mean    44.220000    0.410000  100.844444    0.380000       0.45
# std     24.878931    0.494311    2.054926    0.487832       0.50
# min      5.000000    0.000000   98.000000    0.000000       0.00
# 25%     20.000000    0.000000   99.000000    0.000000       0.00
# 50%     45.000000    0.000000  101.000000    0.000000       0.00
# 75%     66.500000    1.000000  102.750000    1.000000       1.00
# max     84.000000    1.000000  104.000000    1.000000       1.00

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.dropna()
# Out:
#     age  gender  fever  cough       city  has_covid
# 0    60       1  103.0      0    Kolkata          0
# 1    27       1  100.0      0      Delhi          1
# 2    42       1  101.0      0      Delhi          0
# 3    31       0   98.0      0    Kolkata          0
# 4    65       0  101.0      0     Mumbai          0
# ..  ...     ...    ...    ...        ...        ...
# 95   12       0  104.0      0  Bangalore          0
# 96   51       0  101.0      1    Kolkata          1
# 97   20       0  101.0      0  Bangalore          0
# 98    5       0   98.0      1     Mumbai          0
# 99   10       0   98.0      1    Kolkata          1
#
# [90 rows x 6 columns]

# %%
i=df.ndim
i
# Out:
# 2

# %%
s=df.shape
s
# Out:
# (100, 6)

# %%
s=df.size
s
# Out:
# 600

# %%
a=df.count()
a
# Out:
# age          100
# gender       100
# fever         90
# cough        100
# city         100
# has_covid    100
# dtype: int64

# %%
a=df.max()
a
# Out:
# age              84
# gender            1
# fever         104.0
# cough             1
# city         Mumbai
# has_covid         1
# dtype: object

# %%
b=df.min()
b
# Out:
# age                  5
# gender               0
# fever             98.0
# cough                0
# city         Bangalore
# has_covid            0
# dtype: object

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
a=df.empty
a
# Out:
# False

# %%
p = df.sort_values(by='age')
p
# Out:
#     age  gender  fever  cough       city  has_covid
# 98    5       0   98.0      1     Mumbai          0
# 75    5       1  102.0      0    Kolkata          1
# 88    5       0  100.0      0    Kolkata          0
# 59    6       0  104.0      0    Kolkata          1
# 77    8       0  101.0      0    Kolkata          0
# ..  ...     ...    ...    ...        ...        ...
# 35   82       0  102.0      1  Bangalore          0
# 72   83       0  101.0      0    Kolkata          0
# 53   83       1   98.0      0      Delhi          1
# 31   83       1  103.0      0    Kolkata          0
# 5    84       0    NaN      0  Bangalore          1
#
# [100 rows x 6 columns]

# %%
a = df.filter(items = [3,4], axis=0)
a
# Out:
#    age  gender  fever  cough     city  has_covid
# 3   31       0   98.0      0  Kolkata          0
# 4   65       0  101.0      0   Mumbai          0

# %%
df['half']=df['fever'].where(df['fever']>100,other = 0)
df.head(10)
# Out:
#    age  gender  fever  cough       city  has_covid   half
# 0   60       1  103.0      0    Kolkata          0  103.0
# 1   27       1  100.0      0      Delhi          1    0.0
# 2   42       1  101.0      0      Delhi          0  101.0
# 3   31       0   98.0      0    Kolkata          0    0.0
# 4   65       0  101.0      0     Mumbai          0  101.0
# 5   84       0    NaN      0  Bangalore          1    0.0
# 6   14       1  101.0      1  Bangalore          0  101.0
# 7   20       0    NaN      1     Mumbai          1    0.0
# 8   19       0  100.0      1  Bangalore          0    0.0
# 9   64       0  101.0      0      Delhi          0  101.0
