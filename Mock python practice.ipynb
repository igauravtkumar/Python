# %%
# 1. Write a Python program to find the maximum element in a list of numbers without
# max functions
# numbers = [10, 20, 4, 45, 99]
# The maximum element is: 99
list1= [10, 20, 4, 45, 99]
max=list1[0]
for i in list1:
  if i > max:
    max = i
print(max)
# Out:
# 99

# %%
numbers = [10, 20, 30, 40]
sum=0
for i in numbers:
  sum=sum+i
print(sum)
# Out:
# 100

# %%
numbers = [1, 2, 3, 4, 5]
for i in range(0,len(numbers)):
  for j in range(i+1,len(numbers)):
    numbers[i],numbers[j]=numbers[j],numbers[i]
print(numbers)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]
list1=[]
for i in numbers:
  if i not in list1:
    list1.append(i)
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [5, 4, 3, 2, 1]
for i in range(0,len(numbers)):
  for j in range(i+1,len(numbers)):
    numbers[i],numbers[j]=numbers[j],numbers[i]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [1, 2, 3, 4, 3, 5, 6]
target=6
pair=[]
for i in range(0,len(numbers)):
  for j in range(i+1,len(numbers)):
    if numbers[i]+numbers[j]==target:
      pair.append((numbers[i],numbers[j]))
print(pair)
# Out:
# [(1, 5), (2, 4), (3, 3)]

# %%
numbers = [1, 2, 3, 4, 5]
sum=0
for i in range(1,len(numbers)-1):
  sum=sum+numbers[i]
print(sum)
# Out:
# 9

# %%
numbers = [1, 2, 3, 3, 2, 1]
i=0
j=len(numbers)-1
a=1
while i < j:
  if numbers[i]==numbers[j]:
    i+=1
    j-=1
  else:
    a=0
    break
if a:
  print('palindrome number ', True)
else:
  print('Not',False)
# Out:
# palindrome number  True

# %%
def func(numbers):
  duplicate=[]
  for i in numbers:
    if i not in duplicate:
      duplicate.append(i)
  return duplicate
numbers = [1, 2, 3, 2, 4, 5, 1, 6]
print(func(numbers))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]
list3=[]
for i in list1:
  for j in list2:
    if i==j:
      list3.append(i)
print(list3)
# Out:
# [3, 4, 5]

# %%
# Find Missing Number in a List
list1=[3,5,6,7,8]
for i in range(3,9):
  if i not in list1:
    print(i)
# Out:
# 4

# %%
numbers = [4, 5, 7, 2, 0, 4, 5, 2]
for i in numbers:
  if numbers.count(i)==1:
    print(i)
    break
# Out:
# 7

# %%
numbers = [0, 1, 0, 3, 12]
i=0
for j in range(0,len(numbers)):
  if numbers[j]!=0:
    numbers[i],numbers[j]=numbers[j],numbers[i]
    i+=1
print(numbers)
# Out:
# [1, 3, 12, 0, 0]

# %%
numbers = [1, 3, 2, 6, 5, 8, 7]
list1=[]
for i in range(0,len(numbers)):
  for j in range(i+1,len(numbers)):
    if numbers[i]<numbers[i+1] and numbers[i+1] not in list1:
      list1.append(numbers[i+1])
print(list1)
# Out:
# [3, 6, 8]

# %%
numbers = [-1, 0, 1, 2, -1, -4]
li=[]
numbers.sort()
for i in range(0,len(numbers)):
  k=i+1
  j=len(numbers)-1
  while k < j:
    if numbers[i]+numbers[j]+numbers[k]==0:
      if [numbers[i],numbers[j],numbers[k]] not in li:
        li.append((numbers[i],numbers[j],numbers[k]))
      k+=1
      j-=1
    elif numbers[i]+numbers[j]+numbers[k] < 0:
      k+=1
    else:
      j-=1
print(li)
# Out:
# [(-1, 2, -1), (-1, 1, 0), (-1, 1, 0)]

# %%
l1=[10,20,300]
l2=[40,50,60]
mydict={}
if len(l1)==len(l2):
  for i in range(len(l1)):
    mydict[l1[i]]=l2[i]
else:
  print('both have not same length')
print(mydict)
# Out:
# {10: 40, 20: 50, 300: 60}
